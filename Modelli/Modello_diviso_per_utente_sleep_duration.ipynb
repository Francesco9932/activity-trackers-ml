# %%
train_and_save = False

# %% [markdown]
# # Import

# %% [markdown]
# ### Librerie

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from keras.models import Sequential, Model
from keras.layers import *
from sklearn.metrics import *
from keras.optimizers import Adam
from statsmodels.tsa.seasonal import seasonal_decompose
import keras.backend as K
from tensorflow import keras
from tensorflow.keras import layers
import time
from math import sqrt
import json
from efficientnet.tfkeras import EfficientNetB4

# %% [markdown]
# ### Dataset

# %%
dataset = pd.read_csv('../dati_continui_con_id.csv')

# %%
dataset[160:180]
# Out:
#                                       user_id        date     steps  bedin  \
# 160  2bc16eda651db5936cd31e735c815296fc1579d9  2017-02-10   5305.23  25.26
# 161  2bc16eda651db5936cd31e735c815296fc1579d9  2017-02-11   7534.40  23.03
# 162  2bc16eda651db5936cd31e735c815296fc1579d9  2017-03-08   4560.29  23.53
# 163  2bc16eda651db5936cd31e735c815296fc1579d9  2017-03-09   6990.77  23.16
# 164  2bc16eda651db5936cd31e735c815296fc1579d9  2017-03-10   8324.80  23.42
# 165  2bc16eda651db5936cd31e735c815296fc1579d9  2017-03-11   6052.50  23.17
# 166  2bc16eda651db5936cd31e735c815296fc1579d9  2017-03-12   7725.14  21.67
# 167  2bc16eda651db5936cd31e735c815296fc1579d9  2017-03-13  10042.03  21.28
# 168  2bc16eda651db5936cd31e735c815296fc1579d9  2017-03-14   7957.16  25.40
# 169  ce96039ca66a9b98f97b202c177cf0ef7d4aa97d  2016-04-19   6689.42  23.37
# 170  ce96039ca66a9b98f97b202c177cf0ef7d4aa97d  2016-04-20   3498.03  20.55
# 171  ce96039ca66a9b98f97b202c177cf0ef7d4aa97d  2016-04-21  10582.15  24.01
# 172  ce96039ca66a9b98f97b202c177cf0ef7d4aa97d  2016-04-22   2414.78  35.94
# 173  ce96039ca66a9b98f97b202c177cf0ef7d4aa97d  2016-04-23   5855.37  11.79
# 174  ce96039ca66a9b98f97b202c177cf0ef7d4aa97d  2016-04-24   6977.67  25.82
# 175  ce96039ca66a9b98f97b202c177cf0ef7d4aa97d  2016-04-25   8375.33  26.55
# 176  ce96039ca66a9b98f97b202c177cf0ef7d4aa97d  2016-04-26   9268.30  21.00
# 177  ce96039ca66a9b98f97b202c177cf0ef7d4aa97d  2016-04-27   7086.95  22.68
# 178  ce96039ca66a9b98f97b202c177cf0ef7d4aa97d  2016-04-28  13633.74  22.86
# 179  ce96039ca66a9b98f97b202c177cf0ef7d4aa97d  2016-04-29   8804.95  23.24
#
#      bedout  sleep duration  deepduration  lightduration
# 160    6.33            4.60          1.72           2.88
# 161    7.69            8.53          4.22           4.34
# 162    6.28            6.51          2.08           4.44
# 163    6.44            7.07          2.84           4.24
# 164    5.90            6.35          2.26           4.11
# 165    6.18            6.73          2.86           3.90
# 166    6.95            8.72          3.79           4.98
# 167    5.59            8.08          2.37           5.71
# 168    7.71            6.16          2.24           3.91
# 169    6.47            6.53          1.18           3.83
# 170   14.52           12.72          3.84           6.84
# 171    8.51            7.40          1.98           4.30
# 172   21.64            0.63          0.05           0.58
# 173   13.74           14.81          3.92           7.83
# 174   11.74            9.55          2.17           5.74
# 175    8.36            5.82          1.43           3.43
# 176    7.28            8.29          2.14           4.66
# 177    8.99           10.36          2.73           6.10
# 178    8.26            8.14          1.62           4.91
# 179    9.63            9.84          2.50           5.57

# %%
# creo una lista di di dataframe dove ogni elemento è l'insieme delle date per utente
utenti = []
# carico elenco utenti per scorrere tutti gli id
elenco_utenti = pd.read_csv('../../dataset/userinfo.csv')
elenco_utenti.drop(elenco_utenti.columns[[0, 3]], axis=1, inplace=True)
elenco_utenti.columns = ['user_id', 'timezone', 'sex', 'age', 'height']
elenco_utenti.head()
# Out:
#                                     user_id timezone     sex  age  height
# 0  fe5d7aacd82682e68d94ea1e6aa33a1e858337f7      PDT  Female   39     175
# 1  88359b8e24f4d6b758fb4566860ba9842fc5b350      UTC    Male   26     179
# 2  e061ccf5eece921027f618686a5aa2412d753b6b      PDT  Female   27     169
# 3  2e88aac4e69049d0845a5e2dce661ae8f4f55239      UTC    Male   61     177
# 4  b4e87340761e4c917db734cd52f56ed9abd0b314      UTC    Male   48     167

# %%
dataset.set_index(['user_id','date'], inplace=True)
dataset
# Out:
#                                                        steps  bedin  bedout  \
# user_id                                  date
# 2bc16eda651db5936cd31e735c815296fc1579d9 2016-04-19  7716.87  24.08    6.81
#                                          2016-04-20  7647.55  27.36    6.50
#                                          2016-04-21  6041.68  23.79    7.93
#                                          2016-04-22  5094.85  25.94    6.44
#                                          2016-04-23  4428.15  25.50   11.75
# ...                                                      ...    ...     ...
# b2caf89287780fcb5cc28c092dc5d4eacb931e88 2017-03-27  5573.72  21.02    6.36
#                                          2017-03-28  6935.26  20.89    7.32
#                                          2017-03-29  4976.99  20.86    7.07
#                                          2017-03-30  3719.77  26.25    7.91
#                                          2017-03-31  9060.18  22.75    7.20
#
#                                                      sleep duration  \
# user_id                                  date
# 2bc16eda651db5936cd31e735c815296fc1579d9 2016-04-19            5.98
#                                          2016-04-20            3.00
#                                          2016-04-21            7.61
#                                          2016-04-22            4.59
#                                          2016-04-23            9.91
# ...                                                             ...
# b2caf89287780fcb5cc28c092dc5d4eacb931e88 2017-03-27            8.87
#                                          2017-03-28            9.17
#                                          2017-03-29            9.27
#                                          2017-03-30            5.30
#                                          2017-03-31            7.80
#
#                                                      deepduration  \
# user_id                                  date
# 2bc16eda651db5936cd31e735c815296fc1579d9 2016-04-19          1.08
#                                          2016-04-20          1.61
#                                          2016-04-21          3.40
#                                          2016-04-22          1.28
#                                          2016-04-23          4.98
# ...                                                           ...
# b2caf89287780fcb5cc28c092dc5d4eacb931e88 2017-03-27          4.71
#                                          2017-03-28          5.23
#                                          2017-03-29          5.45
#                                          2017-03-30          2.65
#                                          2017-03-31          4.07
#
#                                                      lightduration
# user_id                                  date
# 2bc16eda651db5936cd31e735c815296fc1579d9 2016-04-19           4.87
#                                          2016-04-20           1.37
#                                          2016-04-21           4.22
#                                          2016-04-22           3.33
#                                          2016-04-23           4.84
# ...                                                            ...
# b2caf89287780fcb5cc28c092dc5d4eacb931e88 2017-03-27           4.16
#                                          2017-03-28           3.92
#                                          2017-03-29           3.81
#                                          2017-03-30           2.64
#                                          2017-03-31           3.69
#
# [979313 rows x 6 columns]

# %%
# inserisco per ogni elemento della lista il dataframe relativo ad un utente presente nel dataset
for i, r in elenco_utenti.iterrows():
    utente = r['user_id']
    if utente in dataset.index:
        utenti.append(dataset.loc[utente])

# %%
# elimina stagionalitò
senza_stag = []
#stato = 0
for corrente in utenti:
    #print(str(stato) + " / 7984 ")
    #stato = stato+1;
    if len(corrente) >=14:
        lista_stag = []
        lista_stag.append(corrente[['steps']].squeeze() - seasonal_decompose(corrente[['steps']], model='additive', period = 7).seasonal)
        lista_stag.append(corrente[['bedin']].squeeze() - seasonal_decompose(corrente[['bedin']], model='additive', period = 7).seasonal)
        lista_stag.append(corrente[['bedout']].squeeze() - seasonal_decompose(corrente[['bedout']], model='additive', period = 7).seasonal)
        lista_stag.append(corrente[['sleep duration']].squeeze() - seasonal_decompose(corrente[['sleep duration']], model='additive', period = 7).seasonal)
        lista_stag.append(corrente[['deepduration']].squeeze()  - seasonal_decompose(corrente[['deepduration']], model='additive', period = 7).seasonal)
        lista_stag.append(corrente[['lightduration']].squeeze() - seasonal_decompose(corrente[['lightduration']], model='additive', period = 7).seasonal)
        frame = {'steps' : lista_stag[0], 'bedin' : lista_stag[1], 'bedout' : lista_stag[2], 'sleep duration' : lista_stag[3], 'deepduration' : lista_stag[4], 'lightduration' : lista_stag[5]}
        senza_stag.append(pd.DataFrame(frame))
utenti = senza_stag

# %%
# Funzione normalizzazione
scaler = MinMaxScaler(feature_range=(0,1))
def normalizza(dat):
    df_for_training_scaled = scaler.fit_transform(dat)
    return df_for_training_scaled

# %%
# Adesso normalizza ogni dataset
utenti_normalizzati = []
for u in utenti:
    utenti_normalizzati.append(normalizza(u))

# %%
#n_past is the number of step we will look in the past to predict the next target value.
col2pred = 3  # 0:steps, 1:bedin, 2:bedout, 3:sleep duration, 4:deep duration, 5:lightduration
window_size = 7
def createXY(dataset,n_past):
    dataX = []
    dataY = []
    for i in range(n_past, len(dataset)):
            #per ogni feature fa l'append dei precedenti
            dataX.append(dataset[i - n_past:i, 0:dataset.shape[1]])  
            dataY.append(dataset[i,col2pred])
    return np.array(dataX),np.array(dataY)

# %%
n_utenti_train = 6500

# %%
# crea insieme di train
train_lista = utenti_normalizzati[:n_utenti_train]

trainX_lista = []
trainY_lista = []

for t in train_lista:
    trainX_temp, trainY_temp = createXY(t,window_size)
    if len(trainX_temp.shape) == 3 and len(trainY_temp.shape) == 1:
        trainX_lista.append(trainX_temp)
        trainY_lista.append(trainY_temp)

trainX = np.concatenate(trainX_lista)
trainY = np.concatenate(trainY_lista)

# %%
# crea insieme di test
test_lista = utenti_normalizzati[n_utenti_train:]

testX_lista = []
testY_lista = []

for t in test_lista:
    testX_temp, testY_temp = createXY(t,window_size)
    if len(testX_temp.shape) == 3 and len(testY_temp.shape) == 1:
        testX_lista.append(testX_temp)
        testY_lista.append(testY_temp)

testX = np.concatenate(testX_lista)
testY = np.concatenate(testY_lista)

# %%
print(trainX.shape, testX.shape, trainY.shape, testY.shape)
# Out:
# (819942, 7, 6) (101933, 7, 6) (819942,) (101933,)

# %%
# features num
features_num = dataset.shape[1]
features_num
# Out:
# 6

# %% [markdown]
# # Metriche

# %%
def metrics(model, trainX, trainY, testX, testY, history):
    
    # stampa metriche
    score_train = model.evaluate(trainX, trainY, verbose = 0)
    print("**********TRAIN-SET***********")
    print("MSE: {}".format(score_train[1]))
    print("RMSE: {}".format(sqrt(score_train[1])))
    print("MAE: {}".format(score_train[2]))
    
    score_test = model.evaluate(testX, testY, verbose = 0)
    print("**********TEST-SET***********")
    print("MSE: {}".format(score_test[1]))
    print("RMSE: {}".format(sqrt(score_test[1])))
    print("MAE: {}".format(score_test[2]))

    #plot predizioni
    prediction_test=model.predict(testX, verbose = 0)
    prediction_copies_test_array = np.repeat(prediction_test,features_num, axis=-1)
    pred_test=scaler.inverse_transform(np.reshape(prediction_copies_test_array,(len(prediction_test),features_num)))[:,col2pred]
    true_value_test_copies_array = np.repeat(testY,features_num, axis=-1)
    true_value_test=scaler.inverse_transform(np.reshape(true_value_test_copies_array,(len(testY),features_num)))[:,col2pred]
    
    plt.plot(true_value_test[:150], color='red', label='Real sleep duration')
    plt.plot(pred_test[:150], color='blue', label='Predicted sleep duration')
    plt.title('Sleep duration Prediction')
    plt.xlabel('Time')
    plt.ylabel('Sleep duration')
    plt.legend()
    plt.show()
    
    # plot andamento loss
    plt.plot(history['loss'])
    plt.plot(history['val_loss'])
    plt.title('model loss (mse)')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='upper left')
    plt.show()
    
    # plot andamento loss
    plt.plot(history['mae'])
    plt.plot(history['val_mae'])
    plt.title('model mae')
    plt.ylabel('mae')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='upper left')
    plt.show()

# %% [markdown]
# # Data manipulation

# %%
def values4metrics(model, trainX, trainY, testX, testY):
    prediction_train = model.predict(trainX)
    prediction_train_copies_array = np.repeat(prediction_train, features_num, axis=-1)
    pred_train = scaler.inverse_transform(np.reshape(prediction_train_copies_array, (len(prediction_train), features_num)))[:, col2pred]
    true_value_train_copies_array = np.repeat(trainY, features_num, axis=-1)
    true_value_train = scaler.inverse_transform(np.reshape(true_value_train_copies_array, (len(trainY), features_num)))[:, col2pred]

    prediction_test=model.predict(testX)
    prediction_copies_test_array = np.repeat(prediction_test,features_num, axis=-1)
    pred_test=scaler.inverse_transform(np.reshape(prediction_copies_test_array,(len(prediction_test),features_num)))[:,col2pred]
    true_value_test_copies_array = np.repeat(testY,features_num, axis=-1)
    true_value_test=scaler.inverse_transform(np.reshape(true_value_test_copies_array,(len(testY),features_num)))[:,col2pred]
    
    return true_value_train, pred_train, true_value_test, pred_test

# %% [markdown]
# # Architetture di supporto

# %%
class Time2Vec(Layer):

    def __init__(self, output_dimension=None, **kwargs):
        self.output_dimension = output_dimension
        super(Time2Vec, self).__init__(**kwargs)

    def get_config(self):
        config = super().get_config()
        config.update({
            "output_dimension": self.output_dimension,
        })
        return config

    def build(self, input_shape):

        self.W = self.add_weight(name='W',
                                shape=(input_shape[-1], self.output_dimension),
                                initializer='uniform',
                                trainable=True)

        self.P = self.add_weight(name='P',
                                shape=(input_shape[1], self.output_dimension),
                                initializer='uniform',
                                trainable=True)

        self.w = self.add_weight(name='w',
                                shape=(input_shape[1], 1),
                                initializer='uniform',
                                trainable=True)

        self.p = self.add_weight(name='p',
                                shape=(input_shape[1], 1),
                                initializer='uniform',
                                trainable=True)

        super(Time2Vec, self).build(input_shape)

    def call(self, x):

        original = self.w * x + self.p
        sin_trans = K.sin(K.dot(x, self.W) + self.P)

        return K.concatenate([sin_trans, original], -1)

# %%
def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
    # Normalization and Attention
    x = layers.LayerNormalization(epsilon=1e-6)(inputs)
    x = layers.MultiHeadAttention(key_dim=head_size, num_heads=num_heads, dropout=dropout)(x, x)
    x = layers.Dropout(dropout)(x)
    res = x + inputs

    # Feed Forward
    x = layers.LayerNormalization(epsilon=1e-6)(res)
    x = layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu")(x)
    x = layers.Dropout(dropout)(x)
    x = layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(x)
    return x + res

def build_model(input_shape,head_size,num_heads,ff_dim,num_transformer_blocks,mlp_units,dropout=0,mlp_dropout=0):
    inputs = keras.Input(shape=input_shape)
    time_embedding = Time2Vec(120)(inputs)
    #x = inputs
    x = time_embedding
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)
    
    x = layers.GlobalAveragePooling1D(data_format="channels_first")(x)
    for dim in mlp_units:
        x = layers.Dense(dim, activation="tanh")(x)
        x = layers.Dropout(mlp_dropout)(x)
    outputs = layers.Dense(1)(x)
    return keras.Model(inputs, outputs)

input_shape = trainX.shape[1:]

model_transformer = build_model(input_shape,head_size=256,num_heads=2,ff_dim=4,num_transformer_blocks=2,mlp_units=[64],mlp_dropout=0.5,dropout=0.25)

model_transformer.compile(loss="mse", optimizer=keras.optimizers.Adam(learning_rate=0.001), metrics=['mse', 'mae'])

# %% [markdown]
# # Funzione per richiamare i modelli

# %%
def model_recurrent(type = 'gru'):
    model = Sequential()
    
    if type == 'gru': # GRU
        model.add(GRU(256, return_sequences=True, input_shape=(window_size, features_num)))
        model.add(GRU(128, return_sequences=True))
        model.add(GRU(64))
        model.add(Dropout(0.25))
        model.add(Dense(32, activation='tanh'))
        model.add(Dropout(0.5))
        
    if type == 'lstm': # LSTM
        model.add(LSTM(256, return_sequences=True,input_shape=(window_size, features_num)))
        model.add(LSTM(128, return_sequences=True))
        model.add(LSTM(64))
        model.add(Dropout(0.25))
        model.add(Dense(32, activation='tanh'))
        model.add(Dropout(0.5))
    
    if type == 'bidirectional':  # Bidirectional
        model.add(Bidirectional(LSTM(256, return_sequences=True), input_shape=(window_size,features_num)))
        model.add(Bidirectional(LSTM(128, return_sequences=True)))
        model.add(Bidirectional(LSTM(64)))
        model.add(Dropout(0.25))
        model.add(Dense(32, activation='tanh'))
        model.add(Dropout(0.5))   

    if type == 'time2vec':  # Time2Vec
        model.add(Input(shape=(window_size, features_num)))
        model.add(Time2Vec(120))
        model.add(LSTM(128, return_sequences=True))
        model.add(LSTM(64))
        model.add(Dropout(0.25))
        model.add(Dense(32, activation='tanh'))
        model.add(Dropout(0.5))  
        
    if type == 'cnn':  # CNN
        model.add(Conv1D(filters=128, kernel_size=2, activation='tanh', input_shape=(window_size,features_num)))
        model.add(Conv1D(filters=64, kernel_size=2, activation='tanh'))
        model.add(MaxPooling1D(pool_size=2))
        model.add(Flatten())
        model.add(RepeatVector(features_num))
        model.add(LSTM(units=100, return_sequences=True))
        model.add(Dropout(0.2))
        model.add(LSTM(units=100))
        model.add(Dense(100, activation='tanh'))        

    model.add(Dense(1))
    model.compile(loss='mse', optimizer=Adam(learning_rate=0.001), metrics=['mse', 'mae'])
    return model

# %% [markdown]
# # Iperparametri

# %%
n_epoche = 50
batch = 4096 # 8192 - 4096

# %% [markdown]
# # GRU

# %%
model_gru = model_recurrent('gru')
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 7, 256)            202752
#
#  gru_1 (GRU)                 (None, 7, 128)            148224
#
#  gru_2 (GRU)                 (None, 64)                37248
#
#  dropout_9 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  dropout_10 (Dropout)        (None, 32)                0
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 390,337
# Trainable params: 390,337
# Non-trainable params: 0
# _________________________________________________________________

# %%
if train_and_save == True:
    start = time.time()
    history_gru = model_gru.fit(trainX, trainY, epochs = n_epoche, verbose = 1, batch_size = batch, validation_split = 0.2) # 8192
    end = time.time()
    time_gru = end-start
    model_gru.save('./trained_model/SleepDuration/model_gru_e' + str(n_epoche) + "_b" + str(batch) + '.h5')
else:
    model_gru = keras.models.load_model('./trained_model/SleepDuration/model_gru_e' + str(n_epoche) + "_b" + str(batch) + '.h5')
# Out:
# Epoch 1/50
# 161/161 [==============================] - 19s 32ms/step - loss: 0.0484 - mse: 0.0484 - mae: 0.1713 - val_loss: 0.0318 - val_mse: 0.0318 - val_mae: 0.1375
# Epoch 2/50
# 161/161 [==============================] - 4s 24ms/step - loss: 0.0383 - mse: 0.0383 - mae: 0.1524 - val_loss: 0.0313 - val_mse: 0.0313 - val_mae: 0.1361
# Epoch 3/50
# 161/161 [==============================] - 4s 24ms/step - loss: 0.0363 - mse: 0.0363 - mae: 0.1477 - val_loss: 0.0313 - val_mse: 0.0313 - val_mae: 0.1361
# Epoch 4/50
# 161/161 [==============================] - 4s 24ms/step - loss: 0.0348 - mse: 0.0348 - mae: 0.1443 - val_loss: 0.0313 - val_mse: 0.0313 - val_mae: 0.1361
# Epoch 5/50
# 161/161 [==============================] - 4s 24ms/step - loss: 0.0338 - mse: 0.0338 - mae: 0.1417 - val_loss: 0.0308 - val_mse: 0.0308 - val_mae: 0.1343
# Epoch 6/50
# 161/161 [==============================] - 4s 24ms/step - loss: 0.0330 - mse: 0.0330 - mae: 0.1399 - val_loss: 0.0307 - val_mse: 0.0307 - val_mae: 0.1341
# Epoch 7/50
# 161/161 [==============================] - 4s 24ms/step - loss: 0.0325 - mse: 0.0325 - mae: 0.1385 - val_loss: 0.0308 - val_mse: 0.0308 - val_mae: 0.1344
# Epoch 8/50
# 161/161 [==============================] - 4s 24ms/step - loss: 0.0320 - mse: 0.0320 - mae: 0.1373 - val_loss: 0.0307 - val_mse: 0.0307 - val_mae: 0.1342
# Epoch 9/50
# 161/161 [==============================] - 4s 24ms/step - loss: 0.0317 - mse: 0.0317 - mae: 0.1365 - val_loss: 0.0306 - val_mse: 0.0306 - val_mae: 0.1338
# Epoch 10/50
# 161/161 [==============================] - 4s 24ms/step - loss: 0.0315 - mse: 0.0315 - mae: 0.1359 - val_loss: 0.0307 - val_mse: 0.0307 - val_mae: 0.1340
# Epoch 11/50
# 161/161 [==============================] - 4s 24ms/step - loss: 0.0314 - mse: 0.0314 - mae: 0.1356 - val_loss: 0.0306 - val_mse: 0.0306 - val_mae: 0.1339
# Epoch 12/50
# 161/161 [==============================] - 4s 24ms/step - loss: 0.0313 - mse: 0.0313 - mae: 0.1354 - val_loss: 0.0306 - val_mse: 0.0306 - val_mae: 0.1338
# Epoch 13/50
# 161/161 [==============================] - 4s 24ms/step - loss: 0.0312 - mse: 0.0312 - mae: 0.1351 - val_loss: 0.0306 - val_mse: 0.0306 - val_mae: 0.1337
# Epoch 14/50
# 161/161 [==============================] - 4s 24ms/step - loss: 0.0311 - mse: 0.0311 - mae: 0.1350 - val_loss: 0.0305 - val_mse: 0.0305 - val_mae: 0.1335
# Epoch 15/50
# 161/161 [==============================] - 4s 24ms/step - loss: 0.0311 - mse: 0.0311 - mae: 0.1350 - val_loss: 0.0305 - val_mse: 0.0305 - val_mae: 0.1332
# Epoch 16/50
# 161/161 [==============================] - 4s 24ms/step - loss: 0.0311 - mse: 0.0311 - mae: 0.1347 - val_loss: 0.0306 - val_mse: 0.0306 - val_mae: 0.1333
# Epoch 17/50
# 161/161 [==============================] - 4s 24ms/step - loss: 0.0310 - mse: 0.0310 - mae: 0.1346 - val_loss: 0.0305 - val_mse: 0.0305 - val_mae: 0.1335
# Epoch 18/50
# 161/161 [==============================] - 4s 24ms/step - loss: 0.0310 - mse: 0.0310 - mae: 0.1344 - val_loss: 0.0304 - val_mse: 0.0304 - val_mae: 0.1329
# Epoch 19/50
# 161/161 [==============================] - 4s 24ms/step - loss: 0.0309 - mse: 0.0309 - mae: 0.1343 - val_loss: 0.0304 - val_mse: 0.0304 - val_mae: 0.1324
# Epoch 20/50
# 161/161 [==============================] - 4s 24ms/step - loss: 0.0309 - mse: 0.0309 - mae: 0.1341 - val_loss: 0.0303 - val_mse: 0.0303 - val_mae: 0.1329
# Epoch 21/50
# 161/161 [==============================] - 4s 24ms/step - loss: 0.0308 - mse: 0.0308 - mae: 0.1339 - val_loss: 0.0302 - val_mse: 0.0302 - val_mae: 0.1325
# Epoch 22/50
# 161/161 [==============================] - 4s 24ms/step - loss: 0.0308 - mse: 0.0308 - mae: 0.1339 - val_loss: 0.0302 - val_mse: 0.0302 - val_mae: 0.1324
# Epoch 23/50
# 161/161 [==============================] - 4s 24ms/step - loss: 0.0307 - mse: 0.0307 - mae: 0.1337 - val_loss: 0.0302 - val_mse: 0.0302 - val_mae: 0.1324
# Epoch 24/50
# 161/161 [==============================] - 4s 24ms/step - loss: 0.0307 - mse: 0.0307 - mae: 0.1337 - val_loss: 0.0304 - val_mse: 0.0304 - val_mae: 0.1324
# Epoch 25/50
# 161/161 [==============================] - 4s 24ms/step - loss: 0.0307 - mse: 0.0307 - mae: 0.1336 - val_loss: 0.0302 - val_mse: 0.0302 - val_mae: 0.1323
# Epoch 26/50
# 161/161 [==============================] - 4s 24ms/step - loss: 0.0307 - mse: 0.0307 - mae: 0.1336 - val_loss: 0.0302 - val_mse: 0.0302 - val_mae: 0.1323
# Epoch 27/50
# 161/161 [==============================] - 4s 24ms/step - loss: 0.0306 - mse: 0.0306 - mae: 0.1334 - val_loss: 0.0302 - val_mse: 0.0302 - val_mae: 0.1321
# Epoch 28/50
# 161/161 [==============================] - 4s 24ms/step - loss: 0.0307 - mse: 0.0307 - mae: 0.1334 - val_loss: 0.0301 - val_mse: 0.0301 - val_mae: 0.1318
# Epoch 29/50
# 161/161 [==============================] - 4s 24ms/step - loss: 0.0306 - mse: 0.0306 - mae: 0.1333 - val_loss: 0.0301 - val_mse: 0.0301 - val_mae: 0.1319
# Epoch 30/50
# 161/161 [==============================] - 4s 24ms/step - loss: 0.0306 - mse: 0.0306 - mae: 0.1333 - val_loss: 0.0302 - val_mse: 0.0302 - val_mae: 0.1323
# Epoch 31/50
# 161/161 [==============================] - 4s 24ms/step - loss: 0.0306 - mse: 0.0306 - mae: 0.1333 - val_loss: 0.0300 - val_mse: 0.0300 - val_mae: 0.1318
# Epoch 32/50
# 161/161 [==============================] - 4s 24ms/step - loss: 0.0306 - mse: 0.0306 - mae: 0.1332 - val_loss: 0.0301 - val_mse: 0.0301 - val_mae: 0.1318
# Epoch 33/50
# 161/161 [==============================] - 4s 24ms/step - loss: 0.0306 - mse: 0.0306 - mae: 0.1331 - val_loss: 0.0300 - val_mse: 0.0300 - val_mae: 0.1316
# Epoch 34/50
# 161/161 [==============================] - 4s 24ms/step - loss: 0.0306 - mse: 0.0306 - mae: 0.1331 - val_loss: 0.0301 - val_mse: 0.0301 - val_mae: 0.1316
# Epoch 35/50
# 161/161 [==============================] - 4s 24ms/step - loss: 0.0305 - mse: 0.0305 - mae: 0.1331 - val_loss: 0.0302 - val_mse: 0.0302 - val_mae: 0.1323
# Epoch 36/50
# 161/161 [==============================] - 4s 24ms/step - loss: 0.0305 - mse: 0.0305 - mae: 0.1331 - val_loss: 0.0300 - val_mse: 0.0300 - val_mae: 0.1316
# Epoch 37/50
# 161/161 [==============================] - 4s 24ms/step - loss: 0.0305 - mse: 0.0305 - mae: 0.1331 - val_loss: 0.0300 - val_mse: 0.0300 - val_mae: 0.1315
# Epoch 38/50
# 161/161 [==============================] - 4s 24ms/step - loss: 0.0305 - mse: 0.0305 - mae: 0.1329 - val_loss: 0.0300 - val_mse: 0.0300 - val_mae: 0.1320
# Epoch 39/50
# 161/161 [==============================] - 4s 24ms/step - loss: 0.0305 - mse: 0.0305 - mae: 0.1330 - val_loss: 0.0300 - val_mse: 0.0300 - val_mae: 0.1314
# Epoch 40/50
# 161/161 [==============================] - 4s 24ms/step - loss: 0.0305 - mse: 0.0305 - mae: 0.1329 - val_loss: 0.0301 - val_mse: 0.0301 - val_mae: 0.1317
# Epoch 41/50
# 161/161 [==============================] - 4s 24ms/step - loss: 0.0305 - mse: 0.0305 - mae: 0.1329 - val_loss: 0.0300 - val_mse: 0.0300 - val_mae: 0.1318
# Epoch 42/50
# 161/161 [==============================] - 4s 24ms/step - loss: 0.0305 - mse: 0.0305 - mae: 0.1329 - val_loss: 0.0301 - val_mse: 0.0301 - val_mae: 0.1315
# Epoch 43/50
# 161/161 [==============================] - 4s 24ms/step - loss: 0.0304 - mse: 0.0304 - mae: 0.1328 - val_loss: 0.0300 - val_mse: 0.0300 - val_mae: 0.1315
# Epoch 44/50
# 161/161 [==============================] - 4s 24ms/step - loss: 0.0304 - mse: 0.0304 - mae: 0.1328 - val_loss: 0.0300 - val_mse: 0.0300 - val_mae: 0.1316
# Epoch 45/50
# 161/161 [==============================] - 4s 24ms/step - loss: 0.0304 - mse: 0.0304 - mae: 0.1328 - val_loss: 0.0299 - val_mse: 0.0299 - val_mae: 0.1314
# Epoch 46/50
# 161/161 [==============================] - 4s 24ms/step - loss: 0.0304 - mse: 0.0304 - mae: 0.1328 - val_loss: 0.0300 - val_mse: 0.0300 - val_mae: 0.1314
# Epoch 47/50
# 161/161 [==============================] - 4s 24ms/step - loss: 0.0304 - mse: 0.0304 - mae: 0.1327 - val_loss: 0.0299 - val_mse: 0.0299 - val_mae: 0.1316
# Epoch 48/50
# 161/161 [==============================] - 4s 24ms/step - loss: 0.0304 - mse: 0.0304 - mae: 0.1326 - val_loss: 0.0299 - val_mse: 0.0299 - val_mae: 0.1310
# Epoch 49/50
# 161/161 [==============================] - 4s 24ms/step - loss: 0.0304 - mse: 0.0304 - mae: 0.1327 - val_loss: 0.0299 - val_mse: 0.0299 - val_mae: 0.1315
# Epoch 50/50
# 161/161 [==============================] - 4s 24ms/step - loss: 0.0304 - mse: 0.0304 - mae: 0.1327 - val_loss: 0.0299 - val_mse: 0.0299 - val_mae: 0.1310

# %% [markdown]
# # LSTM

# %%
model_lstm = model_recurrent('lstm')
model_lstm.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 7, 256)            269312
#
#  lstm_1 (LSTM)               (None, 7, 128)            197120
#
#  lstm_2 (LSTM)               (None, 64)                49408
#
#  dropout_11 (Dropout)        (None, 64)                0
#
#  dense_4 (Dense)             (None, 32)                2080
#
#  dropout_12 (Dropout)        (None, 32)                0
#
#  dense_5 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 517,953
# Trainable params: 517,953
# Non-trainable params: 0
# _________________________________________________________________

# %%
if train_and_save == True:
    start = time.time()
    history_lstm = model_lstm.fit(trainX, trainY, epochs = n_epoche, verbose = 1, batch_size = batch, validation_split = 0.2) # 8192
    end = time.time()
    time_lstm = end-start
    model_lstm.save('./trained_model/SleepDuration/model_lstm_e' + str(n_epoche) + "_b" + str(batch) + '.h5')
else:
    model_lstm = keras.models.load_model('./trained_model/SleepDuration/model_lstm_e' + str(n_epoche) + "_b" + str(batch) + '.h5')
# Out:
# Epoch 1/50
# 161/161 [==============================] - 10s 35ms/step - loss: 0.0479 - mse: 0.0479 - mae: 0.1709 - val_loss: 0.0330 - val_mse: 0.0330 - val_mae: 0.1408
# Epoch 2/50
# 161/161 [==============================] - 4s 27ms/step - loss: 0.0384 - mse: 0.0384 - mae: 0.1527 - val_loss: 0.0311 - val_mse: 0.0311 - val_mae: 0.1352
# Epoch 3/50
# 161/161 [==============================] - 4s 27ms/step - loss: 0.0366 - mse: 0.0366 - mae: 0.1487 - val_loss: 0.0312 - val_mse: 0.0312 - val_mae: 0.1358
# Epoch 4/50
# 161/161 [==============================] - 4s 27ms/step - loss: 0.0352 - mse: 0.0352 - mae: 0.1452 - val_loss: 0.0309 - val_mse: 0.0309 - val_mae: 0.1344
# Epoch 5/50
# 161/161 [==============================] - 4s 27ms/step - loss: 0.0340 - mse: 0.0340 - mae: 0.1424 - val_loss: 0.0308 - val_mse: 0.0308 - val_mae: 0.1345
# Epoch 6/50
# 161/161 [==============================] - 4s 27ms/step - loss: 0.0331 - mse: 0.0331 - mae: 0.1402 - val_loss: 0.0309 - val_mse: 0.0309 - val_mae: 0.1347
# Epoch 7/50
# 161/161 [==============================] - 4s 27ms/step - loss: 0.0325 - mse: 0.0325 - mae: 0.1385 - val_loss: 0.0310 - val_mse: 0.0310 - val_mae: 0.1351
# Epoch 8/50
# 161/161 [==============================] - 4s 27ms/step - loss: 0.0321 - mse: 0.0321 - mae: 0.1374 - val_loss: 0.0307 - val_mse: 0.0307 - val_mae: 0.1336
# Epoch 9/50
# 161/161 [==============================] - 4s 27ms/step - loss: 0.0318 - mse: 0.0318 - mae: 0.1366 - val_loss: 0.0307 - val_mse: 0.0307 - val_mae: 0.1342
# Epoch 10/50
# 161/161 [==============================] - 4s 27ms/step - loss: 0.0316 - mse: 0.0316 - mae: 0.1361 - val_loss: 0.0307 - val_mse: 0.0307 - val_mae: 0.1338
# Epoch 11/50
# 161/161 [==============================] - 4s 27ms/step - loss: 0.0314 - mse: 0.0314 - mae: 0.1357 - val_loss: 0.0307 - val_mse: 0.0307 - val_mae: 0.1340
# Epoch 12/50
# 161/161 [==============================] - 4s 27ms/step - loss: 0.0313 - mse: 0.0313 - mae: 0.1354 - val_loss: 0.0306 - val_mse: 0.0306 - val_mae: 0.1339
# Epoch 13/50
# 161/161 [==============================] - 4s 27ms/step - loss: 0.0312 - mse: 0.0312 - mae: 0.1351 - val_loss: 0.0306 - val_mse: 0.0306 - val_mae: 0.1338
# Epoch 14/50
# 161/161 [==============================] - 4s 27ms/step - loss: 0.0311 - mse: 0.0311 - mae: 0.1350 - val_loss: 0.0308 - val_mse: 0.0308 - val_mae: 0.1340
# Epoch 15/50
# 161/161 [==============================] - 4s 27ms/step - loss: 0.0311 - mse: 0.0311 - mae: 0.1349 - val_loss: 0.0308 - val_mse: 0.0308 - val_mae: 0.1339
# Epoch 16/50
# 161/161 [==============================] - 4s 27ms/step - loss: 0.0311 - mse: 0.0311 - mae: 0.1348 - val_loss: 0.0305 - val_mse: 0.0305 - val_mae: 0.1333
# Epoch 17/50
# 161/161 [==============================] - 4s 27ms/step - loss: 0.0310 - mse: 0.0310 - mae: 0.1347 - val_loss: 0.0305 - val_mse: 0.0305 - val_mae: 0.1333
# Epoch 18/50
# 161/161 [==============================] - 4s 27ms/step - loss: 0.0310 - mse: 0.0310 - mae: 0.1346 - val_loss: 0.0309 - val_mse: 0.0309 - val_mae: 0.1342
# Epoch 19/50
# 161/161 [==============================] - 4s 27ms/step - loss: 0.0310 - mse: 0.0310 - mae: 0.1345 - val_loss: 0.0304 - val_mse: 0.0304 - val_mae: 0.1329
# Epoch 20/50
# 161/161 [==============================] - 4s 27ms/step - loss: 0.0309 - mse: 0.0309 - mae: 0.1343 - val_loss: 0.0304 - val_mse: 0.0304 - val_mae: 0.1326
# Epoch 21/50
# 161/161 [==============================] - 4s 27ms/step - loss: 0.0309 - mse: 0.0309 - mae: 0.1341 - val_loss: 0.0304 - val_mse: 0.0304 - val_mae: 0.1331
# Epoch 22/50
# 161/161 [==============================] - 4s 27ms/step - loss: 0.0308 - mse: 0.0308 - mae: 0.1340 - val_loss: 0.0303 - val_mse: 0.0303 - val_mae: 0.1325
# Epoch 23/50
# 161/161 [==============================] - 4s 27ms/step - loss: 0.0308 - mse: 0.0308 - mae: 0.1340 - val_loss: 0.0304 - val_mse: 0.0304 - val_mae: 0.1324
# Epoch 24/50
# 161/161 [==============================] - 4s 27ms/step - loss: 0.0308 - mse: 0.0308 - mae: 0.1340 - val_loss: 0.0303 - val_mse: 0.0303 - val_mae: 0.1324
# Epoch 25/50
# 161/161 [==============================] - 4s 27ms/step - loss: 0.0308 - mse: 0.0308 - mae: 0.1339 - val_loss: 0.0303 - val_mse: 0.0303 - val_mae: 0.1320
# Epoch 26/50
# 161/161 [==============================] - 4s 27ms/step - loss: 0.0308 - mse: 0.0308 - mae: 0.1338 - val_loss: 0.0304 - val_mse: 0.0304 - val_mae: 0.1335
# Epoch 27/50
# 161/161 [==============================] - 4s 27ms/step - loss: 0.0307 - mse: 0.0307 - mae: 0.1337 - val_loss: 0.0304 - val_mse: 0.0304 - val_mae: 0.1331
# Epoch 28/50
# 161/161 [==============================] - 4s 28ms/step - loss: 0.0307 - mse: 0.0307 - mae: 0.1336 - val_loss: 0.0302 - val_mse: 0.0302 - val_mae: 0.1325
# Epoch 29/50
# 161/161 [==============================] - 4s 27ms/step - loss: 0.0308 - mse: 0.0308 - mae: 0.1338 - val_loss: 0.0303 - val_mse: 0.0303 - val_mae: 0.1330
# Epoch 30/50
# 161/161 [==============================] - 4s 27ms/step - loss: 0.0307 - mse: 0.0307 - mae: 0.1337 - val_loss: 0.0302 - val_mse: 0.0302 - val_mae: 0.1322
# Epoch 31/50
# 161/161 [==============================] - 4s 27ms/step - loss: 0.0307 - mse: 0.0307 - mae: 0.1336 - val_loss: 0.0303 - val_mse: 0.0303 - val_mae: 0.1325
# Epoch 32/50
# 161/161 [==============================] - 4s 27ms/step - loss: 0.0307 - mse: 0.0307 - mae: 0.1335 - val_loss: 0.0302 - val_mse: 0.0302 - val_mae: 0.1323
# Epoch 33/50
# 161/161 [==============================] - 4s 27ms/step - loss: 0.0306 - mse: 0.0306 - mae: 0.1334 - val_loss: 0.0301 - val_mse: 0.0301 - val_mae: 0.1320
# Epoch 34/50
# 161/161 [==============================] - 4s 27ms/step - loss: 0.0306 - mse: 0.0306 - mae: 0.1334 - val_loss: 0.0301 - val_mse: 0.0301 - val_mae: 0.1318
# Epoch 35/50
# 161/161 [==============================] - 4s 27ms/step - loss: 0.0306 - mse: 0.0306 - mae: 0.1334 - val_loss: 0.0301 - val_mse: 0.0301 - val_mae: 0.1324
# Epoch 36/50
# 161/161 [==============================] - 4s 27ms/step - loss: 0.0306 - mse: 0.0306 - mae: 0.1333 - val_loss: 0.0301 - val_mse: 0.0301 - val_mae: 0.1319
# Epoch 37/50
# 161/161 [==============================] - 4s 27ms/step - loss: 0.0306 - mse: 0.0306 - mae: 0.1333 - val_loss: 0.0303 - val_mse: 0.0303 - val_mae: 0.1331
# Epoch 38/50
# 161/161 [==============================] - 4s 27ms/step - loss: 0.0306 - mse: 0.0306 - mae: 0.1333 - val_loss: 0.0301 - val_mse: 0.0301 - val_mae: 0.1319
# Epoch 39/50
# 161/161 [==============================] - 4s 27ms/step - loss: 0.0306 - mse: 0.0306 - mae: 0.1333 - val_loss: 0.0301 - val_mse: 0.0301 - val_mae: 0.1321
# Epoch 40/50
# 161/161 [==============================] - 4s 27ms/step - loss: 0.0305 - mse: 0.0305 - mae: 0.1332 - val_loss: 0.0301 - val_mse: 0.0301 - val_mae: 0.1325
# Epoch 41/50
# 161/161 [==============================] - 4s 27ms/step - loss: 0.0306 - mse: 0.0306 - mae: 0.1332 - val_loss: 0.0302 - val_mse: 0.0302 - val_mae: 0.1324
# Epoch 42/50
# 161/161 [==============================] - 4s 27ms/step - loss: 0.0305 - mse: 0.0305 - mae: 0.1331 - val_loss: 0.0300 - val_mse: 0.0300 - val_mae: 0.1318
# Epoch 43/50
# 161/161 [==============================] - 4s 27ms/step - loss: 0.0305 - mse: 0.0305 - mae: 0.1331 - val_loss: 0.0300 - val_mse: 0.0300 - val_mae: 0.1318
# Epoch 44/50
# 161/161 [==============================] - 4s 27ms/step - loss: 0.0305 - mse: 0.0305 - mae: 0.1331 - val_loss: 0.0300 - val_mse: 0.0300 - val_mae: 0.1317
# Epoch 45/50
# 161/161 [==============================] - 4s 27ms/step - loss: 0.0305 - mse: 0.0305 - mae: 0.1330 - val_loss: 0.0300 - val_mse: 0.0300 - val_mae: 0.1313
# Epoch 46/50
# 161/161 [==============================] - 4s 27ms/step - loss: 0.0305 - mse: 0.0305 - mae: 0.1331 - val_loss: 0.0301 - val_mse: 0.0301 - val_mae: 0.1315
# Epoch 47/50
# 161/161 [==============================] - 4s 27ms/step - loss: 0.0305 - mse: 0.0305 - mae: 0.1330 - val_loss: 0.0300 - val_mse: 0.0300 - val_mae: 0.1317
# Epoch 48/50
# 161/161 [==============================] - 4s 27ms/step - loss: 0.0305 - mse: 0.0305 - mae: 0.1329 - val_loss: 0.0301 - val_mse: 0.0301 - val_mae: 0.1323
# Epoch 49/50
# 161/161 [==============================] - 4s 27ms/step - loss: 0.0305 - mse: 0.0305 - mae: 0.1329 - val_loss: 0.0300 - val_mse: 0.0300 - val_mae: 0.1317
# Epoch 50/50
# 161/161 [==============================] - 4s 28ms/step - loss: 0.0305 - mse: 0.0305 - mae: 0.1329 - val_loss: 0.0299 - val_mse: 0.0299 - val_mae: 0.1314

# %% [markdown]
# # Bidirectional - LSTM

# %%
model_bi = model_recurrent('bidirectional')
model_bi.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (None, 7, 512)           538624
#  l)
#
#  bidirectional_1 (Bidirectio  (None, 7, 256)           656384
#  nal)
#
#  bidirectional_2 (Bidirectio  (None, 128)              164352
#  nal)
#
#  dropout_13 (Dropout)        (None, 128)               0
#
#  dense_6 (Dense)             (None, 32)                4128
#
#  dropout_14 (Dropout)        (None, 32)                0
#
#  dense_7 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 1,363,521
# Trainable params: 1,363,521
# Non-trainable params: 0
# _________________________________________________________________

# %%
if train_and_save == True:
    start = time.time()
    history_bi = model_bi.fit(trainX, trainY, epochs = n_epoche, verbose = 1, batch_size = batch, validation_split = 0.2) # 8192
    end = time.time()
    time_bi = end-start
    model_bi.save('./trained_model/SleepDuration/model_bidirectional_e' + str(n_epoche) + "_b" + str(batch) + '.h5')
else:
    model_bi = keras.models.load_model('./trained_model/SleepDuration/model_bidirectional_e' + str(n_epoche) + "_b" + str(batch) + '.h5')
# Out:
# Epoch 1/50
# 161/161 [==============================] - 21s 76ms/step - loss: 0.0467 - mse: 0.0467 - mae: 0.1681 - val_loss: 0.0309 - val_mse: 0.0309 - val_mae: 0.1349
# Epoch 2/50
# 161/161 [==============================] - 10s 63ms/step - loss: 0.0383 - mse: 0.0383 - mae: 0.1524 - val_loss: 0.0327 - val_mse: 0.0327 - val_mae: 0.1397
# Epoch 3/50
# 161/161 [==============================] - 10s 63ms/step - loss: 0.0365 - mse: 0.0365 - mae: 0.1483 - val_loss: 0.0310 - val_mse: 0.0310 - val_mae: 0.1351
# Epoch 4/50
# 161/161 [==============================] - 10s 64ms/step - loss: 0.0351 - mse: 0.0351 - mae: 0.1448 - val_loss: 0.0311 - val_mse: 0.0311 - val_mae: 0.1355
# Epoch 5/50
# 161/161 [==============================] - 10s 64ms/step - loss: 0.0340 - mse: 0.0340 - mae: 0.1424 - val_loss: 0.0310 - val_mse: 0.0310 - val_mae: 0.1349
# Epoch 6/50
# 161/161 [==============================] - 10s 63ms/step - loss: 0.0332 - mse: 0.0332 - mae: 0.1402 - val_loss: 0.0307 - val_mse: 0.0307 - val_mae: 0.1341
# Epoch 7/50
# 161/161 [==============================] - 10s 63ms/step - loss: 0.0325 - mse: 0.0325 - mae: 0.1386 - val_loss: 0.0307 - val_mse: 0.0307 - val_mae: 0.1340
# Epoch 8/50
# 161/161 [==============================] - 10s 63ms/step - loss: 0.0321 - mse: 0.0321 - mae: 0.1374 - val_loss: 0.0310 - val_mse: 0.0310 - val_mae: 0.1351
# Epoch 9/50
# 161/161 [==============================] - 10s 63ms/step - loss: 0.0318 - mse: 0.0318 - mae: 0.1366 - val_loss: 0.0307 - val_mse: 0.0307 - val_mae: 0.1338
# Epoch 10/50
# 161/161 [==============================] - 10s 63ms/step - loss: 0.0315 - mse: 0.0315 - mae: 0.1360 - val_loss: 0.0307 - val_mse: 0.0307 - val_mae: 0.1338
# Epoch 11/50
# 161/161 [==============================] - 10s 63ms/step - loss: 0.0314 - mse: 0.0314 - mae: 0.1356 - val_loss: 0.0310 - val_mse: 0.0310 - val_mae: 0.1344
# Epoch 12/50
# 161/161 [==============================] - 10s 63ms/step - loss: 0.0313 - mse: 0.0313 - mae: 0.1354 - val_loss: 0.0307 - val_mse: 0.0307 - val_mae: 0.1341
# Epoch 13/50
# 161/161 [==============================] - 10s 63ms/step - loss: 0.0312 - mse: 0.0312 - mae: 0.1352 - val_loss: 0.0306 - val_mse: 0.0306 - val_mae: 0.1337
# Epoch 14/50
# 161/161 [==============================] - 10s 63ms/step - loss: 0.0312 - mse: 0.0312 - mae: 0.1351 - val_loss: 0.0306 - val_mse: 0.0306 - val_mae: 0.1336
# Epoch 15/50
# 161/161 [==============================] - 10s 63ms/step - loss: 0.0311 - mse: 0.0311 - mae: 0.1349 - val_loss: 0.0306 - val_mse: 0.0306 - val_mae: 0.1336
# Epoch 16/50
# 161/161 [==============================] - 10s 63ms/step - loss: 0.0311 - mse: 0.0311 - mae: 0.1348 - val_loss: 0.0306 - val_mse: 0.0306 - val_mae: 0.1336
# Epoch 17/50
# 161/161 [==============================] - 10s 63ms/step - loss: 0.0311 - mse: 0.0311 - mae: 0.1348 - val_loss: 0.0308 - val_mse: 0.0308 - val_mae: 0.1339
# Epoch 18/50
# 161/161 [==============================] - 10s 63ms/step - loss: 0.0311 - mse: 0.0311 - mae: 0.1348 - val_loss: 0.0309 - val_mse: 0.0309 - val_mae: 0.1338
# Epoch 19/50
# 161/161 [==============================] - 10s 63ms/step - loss: 0.0311 - mse: 0.0311 - mae: 0.1348 - val_loss: 0.0307 - val_mse: 0.0307 - val_mae: 0.1341
# Epoch 20/50
# 161/161 [==============================] - 10s 63ms/step - loss: 0.0311 - mse: 0.0311 - mae: 0.1347 - val_loss: 0.0306 - val_mse: 0.0306 - val_mae: 0.1336
# Epoch 21/50
# 161/161 [==============================] - 10s 63ms/step - loss: 0.0310 - mse: 0.0310 - mae: 0.1347 - val_loss: 0.0305 - val_mse: 0.0305 - val_mae: 0.1334
# Epoch 22/50
# 161/161 [==============================] - 10s 63ms/step - loss: 0.0310 - mse: 0.0310 - mae: 0.1346 - val_loss: 0.0305 - val_mse: 0.0305 - val_mae: 0.1335
# Epoch 23/50
# 161/161 [==============================] - 10s 63ms/step - loss: 0.0311 - mse: 0.0311 - mae: 0.1347 - val_loss: 0.0309 - val_mse: 0.0309 - val_mae: 0.1345
# Epoch 24/50
# 161/161 [==============================] - 10s 63ms/step - loss: 0.0310 - mse: 0.0310 - mae: 0.1347 - val_loss: 0.0306 - val_mse: 0.0306 - val_mae: 0.1333
# Epoch 25/50
# 161/161 [==============================] - 10s 63ms/step - loss: 0.0310 - mse: 0.0310 - mae: 0.1346 - val_loss: 0.0305 - val_mse: 0.0305 - val_mae: 0.1333
# Epoch 26/50
# 161/161 [==============================] - 10s 63ms/step - loss: 0.0310 - mse: 0.0310 - mae: 0.1345 - val_loss: 0.0304 - val_mse: 0.0304 - val_mae: 0.1330
# Epoch 27/50
# 161/161 [==============================] - 10s 63ms/step - loss: 0.0310 - mse: 0.0310 - mae: 0.1345 - val_loss: 0.0304 - val_mse: 0.0304 - val_mae: 0.1332
# Epoch 28/50
# 161/161 [==============================] - 10s 63ms/step - loss: 0.0309 - mse: 0.0309 - mae: 0.1343 - val_loss: 0.0304 - val_mse: 0.0304 - val_mae: 0.1327
# Epoch 29/50
# 161/161 [==============================] - 10s 63ms/step - loss: 0.0309 - mse: 0.0309 - mae: 0.1343 - val_loss: 0.0304 - val_mse: 0.0304 - val_mae: 0.1332
# Epoch 30/50
# 161/161 [==============================] - 10s 63ms/step - loss: 0.0308 - mse: 0.0308 - mae: 0.1341 - val_loss: 0.0304 - val_mse: 0.0304 - val_mae: 0.1327
# Epoch 31/50
# 161/161 [==============================] - 10s 63ms/step - loss: 0.0308 - mse: 0.0308 - mae: 0.1339 - val_loss: 0.0303 - val_mse: 0.0303 - val_mae: 0.1323
# Epoch 32/50
# 161/161 [==============================] - 10s 63ms/step - loss: 0.0308 - mse: 0.0308 - mae: 0.1338 - val_loss: 0.0302 - val_mse: 0.0302 - val_mae: 0.1326
# Epoch 33/50
# 161/161 [==============================] - 10s 63ms/step - loss: 0.0307 - mse: 0.0307 - mae: 0.1337 - val_loss: 0.0301 - val_mse: 0.0301 - val_mae: 0.1319
# Epoch 34/50
# 161/161 [==============================] - 10s 63ms/step - loss: 0.0307 - mse: 0.0307 - mae: 0.1337 - val_loss: 0.0302 - val_mse: 0.0302 - val_mae: 0.1320
# Epoch 35/50
# 161/161 [==============================] - 10s 63ms/step - loss: 0.0307 - mse: 0.0307 - mae: 0.1336 - val_loss: 0.0301 - val_mse: 0.0301 - val_mae: 0.1318
# Epoch 36/50
# 161/161 [==============================] - 10s 63ms/step - loss: 0.0306 - mse: 0.0306 - mae: 0.1335 - val_loss: 0.0301 - val_mse: 0.0301 - val_mae: 0.1319
# Epoch 37/50
# 161/161 [==============================] - 10s 63ms/step - loss: 0.0306 - mse: 0.0306 - mae: 0.1334 - val_loss: 0.0301 - val_mse: 0.0301 - val_mae: 0.1318
# Epoch 38/50
# 161/161 [==============================] - 10s 63ms/step - loss: 0.0306 - mse: 0.0306 - mae: 0.1333 - val_loss: 0.0302 - val_mse: 0.0302 - val_mae: 0.1325
# Epoch 39/50
# 161/161 [==============================] - 10s 63ms/step - loss: 0.0306 - mse: 0.0306 - mae: 0.1333 - val_loss: 0.0303 - val_mse: 0.0303 - val_mae: 0.1332
# Epoch 40/50
# 161/161 [==============================] - 10s 63ms/step - loss: 0.0306 - mse: 0.0306 - mae: 0.1333 - val_loss: 0.0301 - val_mse: 0.0301 - val_mae: 0.1321
# Epoch 41/50
# 161/161 [==============================] - 10s 63ms/step - loss: 0.0306 - mse: 0.0306 - mae: 0.1333 - val_loss: 0.0302 - val_mse: 0.0302 - val_mae: 0.1318
# Epoch 42/50
# 161/161 [==============================] - 10s 63ms/step - loss: 0.0305 - mse: 0.0305 - mae: 0.1331 - val_loss: 0.0305 - val_mse: 0.0305 - val_mae: 0.1331
# Epoch 43/50
# 161/161 [==============================] - 10s 63ms/step - loss: 0.0305 - mse: 0.0305 - mae: 0.1332 - val_loss: 0.0300 - val_mse: 0.0300 - val_mae: 0.1317
# Epoch 44/50
# 161/161 [==============================] - 10s 63ms/step - loss: 0.0306 - mse: 0.0306 - mae: 0.1332 - val_loss: 0.0302 - val_mse: 0.0302 - val_mae: 0.1322
# Epoch 45/50
# 161/161 [==============================] - 10s 63ms/step - loss: 0.0305 - mse: 0.0305 - mae: 0.1332 - val_loss: 0.0302 - val_mse: 0.0302 - val_mae: 0.1316
# Epoch 46/50
# 161/161 [==============================] - 10s 63ms/step - loss: 0.0305 - mse: 0.0305 - mae: 0.1330 - val_loss: 0.0300 - val_mse: 0.0300 - val_mae: 0.1319
# Epoch 47/50
# 161/161 [==============================] - 10s 63ms/step - loss: 0.0305 - mse: 0.0305 - mae: 0.1331 - val_loss: 0.0300 - val_mse: 0.0300 - val_mae: 0.1316
# Epoch 48/50
# 161/161 [==============================] - 10s 63ms/step - loss: 0.0305 - mse: 0.0305 - mae: 0.1329 - val_loss: 0.0300 - val_mse: 0.0300 - val_mae: 0.1320
# Epoch 49/50
# 161/161 [==============================] - 10s 63ms/step - loss: 0.0305 - mse: 0.0305 - mae: 0.1330 - val_loss: 0.0301 - val_mse: 0.0301 - val_mae: 0.1316
# Epoch 50/50
# 161/161 [==============================] - 10s 63ms/step - loss: 0.0305 - mse: 0.0305 - mae: 0.1329 - val_loss: 0.0300 - val_mse: 0.0300 - val_mae: 0.1315

# %% [markdown]
# # Time2Vec - LSTM

# %%
model_t2v = model_recurrent('time2vec')
model_t2v.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time2_vec_1 (Time2Vec)      (None, 7, 126)            1574
#
#  lstm (LSTM)                 (None, 7, 128)            130560
#
#  lstm_1 (LSTM)               (None, 64)                49408
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  dropout_6 (Dropout)         (None, 32)                0
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 183,655
# Trainable params: 183,655
# Non-trainable params: 0
# _________________________________________________________________

# %%
if train_and_save == True:
    start = time.time()
    history_t2v = model_t2v.fit(trainX, trainY, epochs = n_epoche, verbose = 1, batch_size = batch, validation_split = 0.2) # 8192
    end = time.time()
    time_t2v = end-start
    model_t2v.save('./trained_model/SleepDuration/model_time2vec_e' + str(n_epoche) + "_b" + str(batch) + '.h5')
else:
    model_t2v = keras.models.load_model('./trained_model/SleepDuration/model_time2vec_e' + str(n_epoche) + "_b" + str(batch) + '.h5', custom_objects={'Time2Vec': Time2Vec})
# Out:
# Epoch 1/50
# 161/161 [==============================] - 7s 22ms/step - loss: 0.0478 - mse: 0.0478 - mae: 0.1710 - val_loss: 0.0317 - val_mse: 0.0317 - val_mae: 0.1372
# Epoch 2/50
# 161/161 [==============================] - 2s 15ms/step - loss: 0.0384 - mse: 0.0384 - mae: 0.1525 - val_loss: 0.0310 - val_mse: 0.0310 - val_mae: 0.1350
# Epoch 3/50
# 161/161 [==============================] - 2s 15ms/step - loss: 0.0365 - mse: 0.0365 - mae: 0.1484 - val_loss: 0.0314 - val_mse: 0.0314 - val_mae: 0.1364
# Epoch 4/50
# 161/161 [==============================] - 2s 15ms/step - loss: 0.0352 - mse: 0.0352 - mae: 0.1452 - val_loss: 0.0309 - val_mse: 0.0309 - val_mae: 0.1347
# Epoch 5/50
# 161/161 [==============================] - 2s 15ms/step - loss: 0.0340 - mse: 0.0340 - mae: 0.1424 - val_loss: 0.0314 - val_mse: 0.0314 - val_mae: 0.1357
# Epoch 6/50
# 161/161 [==============================] - 2s 15ms/step - loss: 0.0333 - mse: 0.0333 - mae: 0.1405 - val_loss: 0.0311 - val_mse: 0.0311 - val_mae: 0.1349
# Epoch 7/50
# 161/161 [==============================] - 3s 16ms/step - loss: 0.0326 - mse: 0.0326 - mae: 0.1388 - val_loss: 0.0307 - val_mse: 0.0307 - val_mae: 0.1341
# Epoch 8/50
# 161/161 [==============================] - 3s 16ms/step - loss: 0.0322 - mse: 0.0322 - mae: 0.1377 - val_loss: 0.0307 - val_mse: 0.0307 - val_mae: 0.1344
# Epoch 9/50
# 161/161 [==============================] - 2s 15ms/step - loss: 0.0318 - mse: 0.0318 - mae: 0.1368 - val_loss: 0.0308 - val_mse: 0.0308 - val_mae: 0.1343
# Epoch 10/50
# 161/161 [==============================] - 3s 16ms/step - loss: 0.0316 - mse: 0.0316 - mae: 0.1362 - val_loss: 0.0306 - val_mse: 0.0306 - val_mae: 0.1338
# Epoch 11/50
# 161/161 [==============================] - 2s 15ms/step - loss: 0.0314 - mse: 0.0314 - mae: 0.1357 - val_loss: 0.0306 - val_mse: 0.0306 - val_mae: 0.1338
# Epoch 12/50
# 161/161 [==============================] - 2s 15ms/step - loss: 0.0312 - mse: 0.0312 - mae: 0.1353 - val_loss: 0.0306 - val_mse: 0.0306 - val_mae: 0.1336
# Epoch 13/50
# 161/161 [==============================] - 2s 15ms/step - loss: 0.0312 - mse: 0.0312 - mae: 0.1351 - val_loss: 0.0307 - val_mse: 0.0307 - val_mae: 0.1340
# Epoch 14/50
# 161/161 [==============================] - 2s 15ms/step - loss: 0.0312 - mse: 0.0312 - mae: 0.1350 - val_loss: 0.0306 - val_mse: 0.0306 - val_mae: 0.1337
# Epoch 15/50
# 161/161 [==============================] - 2s 15ms/step - loss: 0.0311 - mse: 0.0311 - mae: 0.1348 - val_loss: 0.0308 - val_mse: 0.0308 - val_mae: 0.1344
# Epoch 16/50
# 161/161 [==============================] - 2s 15ms/step - loss: 0.0311 - mse: 0.0311 - mae: 0.1348 - val_loss: 0.0307 - val_mse: 0.0307 - val_mae: 0.1337
# Epoch 17/50
# 161/161 [==============================] - 2s 15ms/step - loss: 0.0311 - mse: 0.0311 - mae: 0.1349 - val_loss: 0.0307 - val_mse: 0.0307 - val_mae: 0.1332
# Epoch 18/50
# 161/161 [==============================] - 2s 15ms/step - loss: 0.0311 - mse: 0.0311 - mae: 0.1347 - val_loss: 0.0306 - val_mse: 0.0306 - val_mae: 0.1338
# Epoch 19/50
# 161/161 [==============================] - 2s 15ms/step - loss: 0.0310 - mse: 0.0310 - mae: 0.1347 - val_loss: 0.0306 - val_mse: 0.0306 - val_mae: 0.1331
# Epoch 20/50
# 161/161 [==============================] - 2s 15ms/step - loss: 0.0310 - mse: 0.0310 - mae: 0.1347 - val_loss: 0.0306 - val_mse: 0.0306 - val_mae: 0.1340
# Epoch 21/50
# 161/161 [==============================] - 2s 15ms/step - loss: 0.0310 - mse: 0.0310 - mae: 0.1344 - val_loss: 0.0305 - val_mse: 0.0305 - val_mae: 0.1331
# Epoch 22/50
# 161/161 [==============================] - 2s 15ms/step - loss: 0.0309 - mse: 0.0309 - mae: 0.1343 - val_loss: 0.0305 - val_mse: 0.0305 - val_mae: 0.1325
# Epoch 23/50
# 161/161 [==============================] - 2s 15ms/step - loss: 0.0309 - mse: 0.0309 - mae: 0.1342 - val_loss: 0.0303 - val_mse: 0.0303 - val_mae: 0.1327
# Epoch 24/50
# 161/161 [==============================] - 2s 15ms/step - loss: 0.0308 - mse: 0.0308 - mae: 0.1340 - val_loss: 0.0303 - val_mse: 0.0303 - val_mae: 0.1329
# Epoch 25/50
# 161/161 [==============================] - 2s 15ms/step - loss: 0.0308 - mse: 0.0308 - mae: 0.1338 - val_loss: 0.0305 - val_mse: 0.0305 - val_mae: 0.1334
# Epoch 26/50
# 161/161 [==============================] - 2s 15ms/step - loss: 0.0307 - mse: 0.0307 - mae: 0.1338 - val_loss: 0.0302 - val_mse: 0.0302 - val_mae: 0.1323
# Epoch 27/50
# 161/161 [==============================] - 2s 15ms/step - loss: 0.0307 - mse: 0.0307 - mae: 0.1336 - val_loss: 0.0303 - val_mse: 0.0303 - val_mae: 0.1322
# Epoch 28/50
# 161/161 [==============================] - 2s 15ms/step - loss: 0.0307 - mse: 0.0307 - mae: 0.1336 - val_loss: 0.0302 - val_mse: 0.0302 - val_mae: 0.1320
# Epoch 29/50
# 161/161 [==============================] - 2s 15ms/step - loss: 0.0307 - mse: 0.0307 - mae: 0.1335 - val_loss: 0.0302 - val_mse: 0.0302 - val_mae: 0.1321
# Epoch 30/50
# 161/161 [==============================] - 2s 15ms/step - loss: 0.0307 - mse: 0.0307 - mae: 0.1335 - val_loss: 0.0306 - val_mse: 0.0306 - val_mae: 0.1325
# Epoch 31/50
# 161/161 [==============================] - 2s 15ms/step - loss: 0.0307 - mse: 0.0307 - mae: 0.1335 - val_loss: 0.0302 - val_mse: 0.0302 - val_mae: 0.1321
# Epoch 32/50
# 161/161 [==============================] - 2s 15ms/step - loss: 0.0306 - mse: 0.0306 - mae: 0.1334 - val_loss: 0.0301 - val_mse: 0.0301 - val_mae: 0.1319
# Epoch 33/50
# 161/161 [==============================] - 2s 15ms/step - loss: 0.0306 - mse: 0.0306 - mae: 0.1333 - val_loss: 0.0301 - val_mse: 0.0301 - val_mae: 0.1321
# Epoch 34/50
# 161/161 [==============================] - 2s 15ms/step - loss: 0.0306 - mse: 0.0306 - mae: 0.1333 - val_loss: 0.0301 - val_mse: 0.0301 - val_mae: 0.1318
# Epoch 35/50
# 161/161 [==============================] - 2s 15ms/step - loss: 0.0306 - mse: 0.0306 - mae: 0.1333 - val_loss: 0.0302 - val_mse: 0.0302 - val_mae: 0.1321
# Epoch 36/50
# 161/161 [==============================] - 2s 15ms/step - loss: 0.0306 - mse: 0.0306 - mae: 0.1333 - val_loss: 0.0303 - val_mse: 0.0303 - val_mae: 0.1318
# Epoch 37/50
# 161/161 [==============================] - 2s 15ms/step - loss: 0.0306 - mse: 0.0306 - mae: 0.1332 - val_loss: 0.0301 - val_mse: 0.0301 - val_mae: 0.1321
# Epoch 38/50
# 161/161 [==============================] - 2s 15ms/step - loss: 0.0306 - mse: 0.0306 - mae: 0.1332 - val_loss: 0.0301 - val_mse: 0.0301 - val_mae: 0.1314
# Epoch 39/50
# 161/161 [==============================] - 2s 15ms/step - loss: 0.0306 - mse: 0.0306 - mae: 0.1332 - val_loss: 0.0301 - val_mse: 0.0301 - val_mae: 0.1317
# Epoch 40/50
# 161/161 [==============================] - 2s 15ms/step - loss: 0.0306 - mse: 0.0306 - mae: 0.1331 - val_loss: 0.0301 - val_mse: 0.0301 - val_mae: 0.1315
# Epoch 41/50
# 161/161 [==============================] - 2s 15ms/step - loss: 0.0305 - mse: 0.0305 - mae: 0.1331 - val_loss: 0.0301 - val_mse: 0.0301 - val_mae: 0.1323
# Epoch 42/50
# 161/161 [==============================] - 2s 15ms/step - loss: 0.0306 - mse: 0.0306 - mae: 0.1332 - val_loss: 0.0301 - val_mse: 0.0301 - val_mae: 0.1317
# Epoch 43/50
# 161/161 [==============================] - 2s 15ms/step - loss: 0.0306 - mse: 0.0306 - mae: 0.1332 - val_loss: 0.0301 - val_mse: 0.0301 - val_mae: 0.1319
# Epoch 44/50
# 161/161 [==============================] - 2s 15ms/step - loss: 0.0305 - mse: 0.0305 - mae: 0.1331 - val_loss: 0.0301 - val_mse: 0.0301 - val_mae: 0.1325
# Epoch 45/50
# 161/161 [==============================] - 2s 15ms/step - loss: 0.0305 - mse: 0.0305 - mae: 0.1330 - val_loss: 0.0303 - val_mse: 0.0303 - val_mae: 0.1317
# Epoch 46/50
# 161/161 [==============================] - 2s 15ms/step - loss: 0.0306 - mse: 0.0306 - mae: 0.1332 - val_loss: 0.0300 - val_mse: 0.0300 - val_mae: 0.1318
# Epoch 47/50
# 161/161 [==============================] - 2s 15ms/step - loss: 0.0305 - mse: 0.0305 - mae: 0.1331 - val_loss: 0.0302 - val_mse: 0.0302 - val_mae: 0.1322
# Epoch 48/50
# 161/161 [==============================] - 2s 15ms/step - loss: 0.0305 - mse: 0.0305 - mae: 0.1330 - val_loss: 0.0301 - val_mse: 0.0301 - val_mae: 0.1315
# Epoch 49/50
# 161/161 [==============================] - 2s 15ms/step - loss: 0.0305 - mse: 0.0305 - mae: 0.1330 - val_loss: 0.0300 - val_mse: 0.0300 - val_mae: 0.1317
# Epoch 50/50
# 161/161 [==============================] - 2s 15ms/step - loss: 0.0305 - mse: 0.0305 - mae: 0.1329 - val_loss: 0.0300 - val_mse: 0.0300 - val_mae: 0.1313

# %% [markdown]
# # CNN - LSTM

# %%
model_cnn = model_recurrent('cnn')
model_cnn.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_8 (Conv1D)           (None, 6, 128)            1664
#
#  conv1d_9 (Conv1D)           (None, 5, 64)             16448
#
#  max_pooling1d (MaxPooling1D  (None, 2, 64)            0
#  )
#
#  flatten (Flatten)           (None, 128)               0
#
#  repeat_vector (RepeatVector  (None, 6, 128)           0
#  )
#
#  lstm_8 (LSTM)               (None, 6, 100)            91600
#
#  dropout_17 (Dropout)        (None, 6, 100)            0
#
#  lstm_9 (LSTM)               (None, 100)               80400
#
#  dense_10 (Dense)            (None, 100)               10100
#
#  dense_11 (Dense)            (None, 1)                 101
#
# =================================================================
# Total params: 200,313
# Trainable params: 200,313
# Non-trainable params: 0
# _________________________________________________________________

# %%
if train_and_save == True:
    start = time.time()
    history_cnn = model_cnn.fit(trainX, trainY, epochs = n_epoche, verbose = 1, batch_size = batch, validation_split = 0.2) # 8192
    end = time.time()
    time_cnn = end-start
    model_cnn.save('./trained_model/SleepDuration/model_cnn_e' + str(n_epoche) + "_b" + str(batch) + '.h5')
else:
    model_cnn = keras.models.load_model('./trained_model/SleepDuration/model_cnn_e' + str(n_epoche) + "_b" + str(batch) + '.h5')
# Out:
# Epoch 1/50
# 161/161 [==============================] - 14s 27ms/step - loss: 0.0351 - mse: 0.0351 - mae: 0.1437 - val_loss: 0.0312 - val_mse: 0.0312 - val_mae: 0.1355
# Epoch 2/50
# 161/161 [==============================] - 3s 18ms/step - loss: 0.0315 - mse: 0.0315 - mae: 0.1358 - val_loss: 0.0312 - val_mse: 0.0312 - val_mae: 0.1351
# Epoch 3/50
# 161/161 [==============================] - 3s 18ms/step - loss: 0.0313 - mse: 0.0313 - mae: 0.1353 - val_loss: 0.0310 - val_mse: 0.0310 - val_mae: 0.1346
# Epoch 4/50
# 161/161 [==============================] - 3s 18ms/step - loss: 0.0313 - mse: 0.0313 - mae: 0.1353 - val_loss: 0.0309 - val_mse: 0.0309 - val_mae: 0.1347
# Epoch 5/50
# 161/161 [==============================] - 3s 18ms/step - loss: 0.0312 - mse: 0.0312 - mae: 0.1350 - val_loss: 0.0312 - val_mse: 0.0312 - val_mae: 0.1346
# Epoch 6/50
# 161/161 [==============================] - 3s 18ms/step - loss: 0.0311 - mse: 0.0311 - mae: 0.1347 - val_loss: 0.0308 - val_mse: 0.0308 - val_mae: 0.1340
# Epoch 7/50
# 161/161 [==============================] - 3s 18ms/step - loss: 0.0311 - mse: 0.0311 - mae: 0.1345 - val_loss: 0.0308 - val_mse: 0.0308 - val_mae: 0.1339
# Epoch 8/50
# 161/161 [==============================] - 3s 18ms/step - loss: 0.0310 - mse: 0.0310 - mae: 0.1344 - val_loss: 0.0308 - val_mse: 0.0308 - val_mae: 0.1343
# Epoch 9/50
# 161/161 [==============================] - 3s 18ms/step - loss: 0.0310 - mse: 0.0310 - mae: 0.1342 - val_loss: 0.0308 - val_mse: 0.0308 - val_mae: 0.1335
# Epoch 10/50
# 161/161 [==============================] - 3s 18ms/step - loss: 0.0309 - mse: 0.0309 - mae: 0.1340 - val_loss: 0.0308 - val_mse: 0.0308 - val_mae: 0.1341
# Epoch 11/50
# 161/161 [==============================] - 3s 18ms/step - loss: 0.0309 - mse: 0.0309 - mae: 0.1339 - val_loss: 0.0311 - val_mse: 0.0311 - val_mae: 0.1343
# Epoch 12/50
# 161/161 [==============================] - 3s 18ms/step - loss: 0.0309 - mse: 0.0309 - mae: 0.1340 - val_loss: 0.0306 - val_mse: 0.0306 - val_mae: 0.1331
# Epoch 13/50
# 161/161 [==============================] - 3s 18ms/step - loss: 0.0308 - mse: 0.0308 - mae: 0.1337 - val_loss: 0.0306 - val_mse: 0.0306 - val_mae: 0.1333
# Epoch 14/50
# 161/161 [==============================] - 3s 18ms/step - loss: 0.0308 - mse: 0.0308 - mae: 0.1336 - val_loss: 0.0306 - val_mse: 0.0306 - val_mae: 0.1337
# Epoch 15/50
# 161/161 [==============================] - 3s 18ms/step - loss: 0.0307 - mse: 0.0307 - mae: 0.1335 - val_loss: 0.0305 - val_mse: 0.0305 - val_mae: 0.1331
# Epoch 16/50
# 161/161 [==============================] - 3s 18ms/step - loss: 0.0307 - mse: 0.0307 - mae: 0.1334 - val_loss: 0.0306 - val_mse: 0.0306 - val_mae: 0.1333
# Epoch 17/50
# 161/161 [==============================] - 3s 18ms/step - loss: 0.0307 - mse: 0.0307 - mae: 0.1333 - val_loss: 0.0305 - val_mse: 0.0305 - val_mae: 0.1329
# Epoch 18/50
# 161/161 [==============================] - 3s 18ms/step - loss: 0.0306 - mse: 0.0306 - mae: 0.1332 - val_loss: 0.0305 - val_mse: 0.0305 - val_mae: 0.1327
# Epoch 19/50
# 161/161 [==============================] - 3s 18ms/step - loss: 0.0306 - mse: 0.0306 - mae: 0.1332 - val_loss: 0.0305 - val_mse: 0.0305 - val_mae: 0.1326
# Epoch 20/50
# 161/161 [==============================] - 3s 18ms/step - loss: 0.0306 - mse: 0.0306 - mae: 0.1331 - val_loss: 0.0304 - val_mse: 0.0304 - val_mae: 0.1327
# Epoch 21/50
# 161/161 [==============================] - 3s 18ms/step - loss: 0.0306 - mse: 0.0306 - mae: 0.1332 - val_loss: 0.0305 - val_mse: 0.0305 - val_mae: 0.1331
# Epoch 22/50
# 161/161 [==============================] - 3s 18ms/step - loss: 0.0306 - mse: 0.0306 - mae: 0.1331 - val_loss: 0.0307 - val_mse: 0.0307 - val_mae: 0.1337
# Epoch 23/50
# 161/161 [==============================] - 3s 18ms/step - loss: 0.0306 - mse: 0.0306 - mae: 0.1331 - val_loss: 0.0304 - val_mse: 0.0304 - val_mae: 0.1326
# Epoch 24/50
# 161/161 [==============================] - 3s 18ms/step - loss: 0.0306 - mse: 0.0306 - mae: 0.1330 - val_loss: 0.0304 - val_mse: 0.0304 - val_mae: 0.1327
# Epoch 25/50
# 161/161 [==============================] - 3s 18ms/step - loss: 0.0306 - mse: 0.0306 - mae: 0.1330 - val_loss: 0.0304 - val_mse: 0.0304 - val_mae: 0.1329
# Epoch 26/50
# 161/161 [==============================] - 3s 18ms/step - loss: 0.0305 - mse: 0.0305 - mae: 0.1329 - val_loss: 0.0305 - val_mse: 0.0305 - val_mae: 0.1327
# Epoch 27/50
# 161/161 [==============================] - 3s 18ms/step - loss: 0.0305 - mse: 0.0305 - mae: 0.1329 - val_loss: 0.0306 - val_mse: 0.0306 - val_mae: 0.1334
# Epoch 28/50
# 161/161 [==============================] - 3s 18ms/step - loss: 0.0305 - mse: 0.0305 - mae: 0.1329 - val_loss: 0.0305 - val_mse: 0.0305 - val_mae: 0.1328
# Epoch 29/50
# 161/161 [==============================] - 3s 18ms/step - loss: 0.0305 - mse: 0.0305 - mae: 0.1329 - val_loss: 0.0307 - val_mse: 0.0307 - val_mae: 0.1332
# Epoch 30/50
# 161/161 [==============================] - 3s 18ms/step - loss: 0.0305 - mse: 0.0305 - mae: 0.1329 - val_loss: 0.0304 - val_mse: 0.0304 - val_mae: 0.1328
# Epoch 31/50
# 161/161 [==============================] - 3s 18ms/step - loss: 0.0305 - mse: 0.0305 - mae: 0.1328 - val_loss: 0.0304 - val_mse: 0.0304 - val_mae: 0.1325
# Epoch 32/50
# 161/161 [==============================] - 3s 19ms/step - loss: 0.0305 - mse: 0.0305 - mae: 0.1328 - val_loss: 0.0305 - val_mse: 0.0305 - val_mae: 0.1328
# Epoch 33/50
# 161/161 [==============================] - 3s 18ms/step - loss: 0.0305 - mse: 0.0305 - mae: 0.1329 - val_loss: 0.0304 - val_mse: 0.0304 - val_mae: 0.1325
# Epoch 34/50
# 161/161 [==============================] - 3s 18ms/step - loss: 0.0304 - mse: 0.0304 - mae: 0.1327 - val_loss: 0.0304 - val_mse: 0.0304 - val_mae: 0.1326
# Epoch 35/50
# 161/161 [==============================] - 3s 18ms/step - loss: 0.0304 - mse: 0.0304 - mae: 0.1327 - val_loss: 0.0304 - val_mse: 0.0304 - val_mae: 0.1330
# Epoch 36/50
# 161/161 [==============================] - 3s 18ms/step - loss: 0.0304 - mse: 0.0304 - mae: 0.1327 - val_loss: 0.0304 - val_mse: 0.0304 - val_mae: 0.1325
# Epoch 37/50
# 161/161 [==============================] - 3s 19ms/step - loss: 0.0304 - mse: 0.0304 - mae: 0.1326 - val_loss: 0.0305 - val_mse: 0.0305 - val_mae: 0.1325
# Epoch 38/50
# 161/161 [==============================] - 3s 18ms/step - loss: 0.0304 - mse: 0.0304 - mae: 0.1326 - val_loss: 0.0304 - val_mse: 0.0304 - val_mae: 0.1323
# Epoch 39/50
# 161/161 [==============================] - 3s 18ms/step - loss: 0.0304 - mse: 0.0304 - mae: 0.1326 - val_loss: 0.0304 - val_mse: 0.0304 - val_mae: 0.1329
# Epoch 40/50
# 161/161 [==============================] - 3s 19ms/step - loss: 0.0304 - mse: 0.0304 - mae: 0.1326 - val_loss: 0.0307 - val_mse: 0.0307 - val_mae: 0.1329
# Epoch 41/50
# 161/161 [==============================] - 3s 18ms/step - loss: 0.0304 - mse: 0.0304 - mae: 0.1326 - val_loss: 0.0305 - val_mse: 0.0305 - val_mae: 0.1333
# Epoch 42/50
# 161/161 [==============================] - 3s 18ms/step - loss: 0.0304 - mse: 0.0304 - mae: 0.1326 - val_loss: 0.0304 - val_mse: 0.0304 - val_mae: 0.1325
# Epoch 43/50
# 161/161 [==============================] - 3s 18ms/step - loss: 0.0303 - mse: 0.0303 - mae: 0.1325 - val_loss: 0.0305 - val_mse: 0.0305 - val_mae: 0.1324
# Epoch 44/50
# 161/161 [==============================] - 3s 18ms/step - loss: 0.0303 - mse: 0.0303 - mae: 0.1324 - val_loss: 0.0304 - val_mse: 0.0304 - val_mae: 0.1326
# Epoch 45/50
# 161/161 [==============================] - 3s 18ms/step - loss: 0.0303 - mse: 0.0303 - mae: 0.1325 - val_loss: 0.0307 - val_mse: 0.0307 - val_mae: 0.1328
# Epoch 46/50
# 161/161 [==============================] - 3s 18ms/step - loss: 0.0303 - mse: 0.0303 - mae: 0.1325 - val_loss: 0.0309 - val_mse: 0.0309 - val_mae: 0.1335
# Epoch 47/50
# 161/161 [==============================] - 3s 18ms/step - loss: 0.0303 - mse: 0.0303 - mae: 0.1323 - val_loss: 0.0304 - val_mse: 0.0304 - val_mae: 0.1324
# Epoch 48/50
# 161/161 [==============================] - 3s 18ms/step - loss: 0.0303 - mse: 0.0303 - mae: 0.1324 - val_loss: 0.0305 - val_mse: 0.0305 - val_mae: 0.1326
# Epoch 49/50
# 161/161 [==============================] - 3s 18ms/step - loss: 0.0303 - mse: 0.0303 - mae: 0.1324 - val_loss: 0.0309 - val_mse: 0.0309 - val_mae: 0.1332
# Epoch 50/50
# 161/161 [==============================] - 3s 18ms/step - loss: 0.0302 - mse: 0.0302 - mae: 0.1323 - val_loss: 0.0304 - val_mse: 0.0304 - val_mae: 0.1327

# %% [markdown]
# # T2V - Transformer

# %%
model_transformer.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 7, 6)]       0           []
#
#  time2_vec (Time2Vec)           (None, 7, 126)       1574        ['input_1[0][0]']
#
#  layer_normalization (LayerNorm  (None, 7, 126)      252         ['time2_vec[0][0]']
#  alization)
#
#  multi_head_attention (MultiHea  (None, 7, 126)      259710      ['layer_normalization[0][0]',
#  dAttention)                                                      'layer_normalization[0][0]']
#
#  dropout (Dropout)              (None, 7, 126)       0           ['multi_head_attention[0][0]']
#
#  tf.__operators__.add (TFOpLamb  (None, 7, 126)      0           ['dropout[0][0]',
#  da)                                                              'time2_vec[0][0]']
#
#  layer_normalization_1 (LayerNo  (None, 7, 126)      252         ['tf.__operators__.add[0][0]']
#  rmalization)
#
#  conv1d (Conv1D)                (None, 7, 4)         508         ['layer_normalization_1[0][0]']
#
#  dropout_1 (Dropout)            (None, 7, 4)         0           ['conv1d[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 7, 126)       630         ['dropout_1[0][0]']
#
#  tf.__operators__.add_1 (TFOpLa  (None, 7, 126)      0           ['conv1d_1[0][0]',
#  mbda)                                                            'tf.__operators__.add[0][0]']
#
#  layer_normalization_2 (LayerNo  (None, 7, 126)      252         ['tf.__operators__.add_1[0][0]']
#  rmalization)
#
#  multi_head_attention_1 (MultiH  (None, 7, 126)      259710      ['layer_normalization_2[0][0]',
#  eadAttention)                                                    'layer_normalization_2[0][0]']
#
#  dropout_2 (Dropout)            (None, 7, 126)       0           ['multi_head_attention_1[0][0]']
#
#  tf.__operators__.add_2 (TFOpLa  (None, 7, 126)      0           ['dropout_2[0][0]',
#  mbda)                                                            'tf.__operators__.add_1[0][0]']
#
#  layer_normalization_3 (LayerNo  (None, 7, 126)      252         ['tf.__operators__.add_2[0][0]']
#  rmalization)
#
#  conv1d_2 (Conv1D)              (None, 7, 4)         508         ['layer_normalization_3[0][0]']
#
#  dropout_3 (Dropout)            (None, 7, 4)         0           ['conv1d_2[0][0]']
#
#  conv1d_3 (Conv1D)              (None, 7, 126)       630         ['dropout_3[0][0]']
#
#  tf.__operators__.add_3 (TFOpLa  (None, 7, 126)      0           ['conv1d_3[0][0]',
#  mbda)                                                            'tf.__operators__.add_2[0][0]']
#
#  global_average_pooling1d (Glob  (None, 7)           0           ['tf.__operators__.add_3[0][0]']
#  alAveragePooling1D)
#
#  dense (Dense)                  (None, 64)           512         ['global_average_pooling1d[0][0]'
#                                                                  ]
#
#  dropout_4 (Dropout)            (None, 64)           0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 1)            65          ['dropout_4[0][0]']
#
# ==================================================================================================
# Total params: 524,855
# Trainable params: 524,855
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
if train_and_save == True:
    start = time.time()
    history_t= model_transformer.fit(trainX, trainY, epochs = n_epoche, verbose = 1, batch_size = batch, validation_split = 0.2) # 8192
    end = time.time()
    time_t = end-start
    model_transformer.save('./trained_model/model_transformer_e' + str(n_epoche) + "_b" + str(batch) + '.h5')
else:
    model_transformer = keras.models.load_model('./trained_model/model_transformer_e' + str(n_epoche) + "_b" + str(batch) + '.h5', custom_objects={'Time2Vec': Time2Vec})
# Out:
# Epoch 1/50
# 161/161 [==============================] - 29s 75ms/step - loss: 0.0443 - mse: 0.0443 - mae: 0.1623 - val_loss: 0.0305 - val_mse: 0.0305 - val_mae: 0.1334
# Epoch 2/50
# 161/161 [==============================] - 12s 72ms/step - loss: 0.0349 - mse: 0.0349 - mae: 0.1444 - val_loss: 0.0307 - val_mse: 0.0307 - val_mae: 0.1344
# Epoch 3/50
# 161/161 [==============================] - 12s 72ms/step - loss: 0.0341 - mse: 0.0341 - mae: 0.1425 - val_loss: 0.0305 - val_mse: 0.0305 - val_mae: 0.1332
# Epoch 4/50
# 161/161 [==============================] - 12s 72ms/step - loss: 0.0335 - mse: 0.0335 - mae: 0.1410 - val_loss: 0.0303 - val_mse: 0.0303 - val_mae: 0.1331
# Epoch 5/50
# 161/161 [==============================] - 12s 72ms/step - loss: 0.0330 - mse: 0.0330 - mae: 0.1395 - val_loss: 0.0314 - val_mse: 0.0314 - val_mae: 0.1365
# Epoch 6/50
# 161/161 [==============================] - 12s 72ms/step - loss: 0.0326 - mse: 0.0326 - mae: 0.1386 - val_loss: 0.0304 - val_mse: 0.0304 - val_mae: 0.1330
# Epoch 7/50
# 161/161 [==============================] - 12s 72ms/step - loss: 0.0321 - mse: 0.0321 - mae: 0.1374 - val_loss: 0.0301 - val_mse: 0.0301 - val_mae: 0.1317
# Epoch 8/50
# 161/161 [==============================] - 12s 72ms/step - loss: 0.0318 - mse: 0.0318 - mae: 0.1365 - val_loss: 0.0302 - val_mse: 0.0302 - val_mae: 0.1321
# Epoch 9/50
# 161/161 [==============================] - 12s 73ms/step - loss: 0.0316 - mse: 0.0316 - mae: 0.1359 - val_loss: 0.0302 - val_mse: 0.0302 - val_mae: 0.1321
# Epoch 10/50
# 161/161 [==============================] - 12s 73ms/step - loss: 0.0314 - mse: 0.0314 - mae: 0.1352 - val_loss: 0.0303 - val_mse: 0.0303 - val_mae: 0.1327
# Epoch 11/50
# 161/161 [==============================] - 12s 73ms/step - loss: 0.0312 - mse: 0.0312 - mae: 0.1348 - val_loss: 0.0305 - val_mse: 0.0305 - val_mae: 0.1330
# Epoch 12/50
# 161/161 [==============================] - 12s 73ms/step - loss: 0.0310 - mse: 0.0310 - mae: 0.1342 - val_loss: 0.0301 - val_mse: 0.0301 - val_mae: 0.1314
# Epoch 13/50
# 161/161 [==============================] - 12s 73ms/step - loss: 0.0309 - mse: 0.0309 - mae: 0.1340 - val_loss: 0.0305 - val_mse: 0.0305 - val_mae: 0.1334
# Epoch 14/50
# 161/161 [==============================] - 12s 73ms/step - loss: 0.0309 - mse: 0.0309 - mae: 0.1340 - val_loss: 0.0304 - val_mse: 0.0304 - val_mae: 0.1332
# Epoch 15/50
# 161/161 [==============================] - 12s 73ms/step - loss: 0.0308 - mse: 0.0308 - mae: 0.1336 - val_loss: 0.0306 - val_mse: 0.0306 - val_mae: 0.1326
# Epoch 16/50
# 161/161 [==============================] - 12s 73ms/step - loss: 0.0307 - mse: 0.0307 - mae: 0.1334 - val_loss: 0.0314 - val_mse: 0.0314 - val_mae: 0.1342
# Epoch 17/50
# 161/161 [==============================] - 12s 73ms/step - loss: 0.0307 - mse: 0.0307 - mae: 0.1333 - val_loss: 0.0303 - val_mse: 0.0303 - val_mae: 0.1323
# Epoch 18/50
# 161/161 [==============================] - 12s 73ms/step - loss: 0.0306 - mse: 0.0306 - mae: 0.1332 - val_loss: 0.0305 - val_mse: 0.0305 - val_mae: 0.1327
# Epoch 19/50
# 161/161 [==============================] - 12s 73ms/step - loss: 0.0306 - mse: 0.0306 - mae: 0.1331 - val_loss: 0.0304 - val_mse: 0.0304 - val_mae: 0.1324
# Epoch 20/50
# 161/161 [==============================] - 12s 73ms/step - loss: 0.0306 - mse: 0.0306 - mae: 0.1330 - val_loss: 0.0300 - val_mse: 0.0300 - val_mae: 0.1315
# Epoch 21/50
# 161/161 [==============================] - 12s 73ms/step - loss: 0.0306 - mse: 0.0306 - mae: 0.1331 - val_loss: 0.0303 - val_mse: 0.0303 - val_mae: 0.1319
# Epoch 22/50
# 161/161 [==============================] - 12s 73ms/step - loss: 0.0305 - mse: 0.0305 - mae: 0.1329 - val_loss: 0.0301 - val_mse: 0.0301 - val_mae: 0.1315
# Epoch 23/50
# 161/161 [==============================] - 12s 73ms/step - loss: 0.0306 - mse: 0.0306 - mae: 0.1331 - val_loss: 0.0300 - val_mse: 0.0300 - val_mae: 0.1313
# Epoch 24/50
# 161/161 [==============================] - 12s 73ms/step - loss: 0.0305 - mse: 0.0305 - mae: 0.1328 - val_loss: 0.0301 - val_mse: 0.0301 - val_mae: 0.1313
# Epoch 25/50
# 161/161 [==============================] - 12s 73ms/step - loss: 0.0305 - mse: 0.0305 - mae: 0.1329 - val_loss: 0.0302 - val_mse: 0.0302 - val_mae: 0.1314
# Epoch 26/50
# 161/161 [==============================] - 12s 73ms/step - loss: 0.0305 - mse: 0.0305 - mae: 0.1329 - val_loss: 0.0304 - val_mse: 0.0304 - val_mae: 0.1317
# Epoch 27/50
# 161/161 [==============================] - 12s 73ms/step - loss: 0.0305 - mse: 0.0305 - mae: 0.1329 - val_loss: 0.0300 - val_mse: 0.0300 - val_mae: 0.1310
# Epoch 28/50
# 161/161 [==============================] - 12s 73ms/step - loss: 0.0304 - mse: 0.0304 - mae: 0.1326 - val_loss: 0.0301 - val_mse: 0.0301 - val_mae: 0.1314
# Epoch 29/50
# 161/161 [==============================] - 12s 73ms/step - loss: 0.0305 - mse: 0.0305 - mae: 0.1327 - val_loss: 0.0302 - val_mse: 0.0302 - val_mae: 0.1313
# Epoch 30/50
# 161/161 [==============================] - 12s 73ms/step - loss: 0.0304 - mse: 0.0304 - mae: 0.1327 - val_loss: 0.0301 - val_mse: 0.0301 - val_mae: 0.1312
# Epoch 31/50
# 161/161 [==============================] - 12s 73ms/step - loss: 0.0304 - mse: 0.0304 - mae: 0.1327 - val_loss: 0.0302 - val_mse: 0.0302 - val_mae: 0.1319
# Epoch 32/50
# 161/161 [==============================] - 12s 73ms/step - loss: 0.0304 - mse: 0.0304 - mae: 0.1327 - val_loss: 0.0305 - val_mse: 0.0305 - val_mae: 0.1331
# Epoch 33/50
# 161/161 [==============================] - 12s 73ms/step - loss: 0.0304 - mse: 0.0304 - mae: 0.1327 - val_loss: 0.0300 - val_mse: 0.0300 - val_mae: 0.1309
# Epoch 34/50
# 161/161 [==============================] - 12s 73ms/step - loss: 0.0304 - mse: 0.0304 - mae: 0.1326 - val_loss: 0.0299 - val_mse: 0.0299 - val_mae: 0.1312
# Epoch 35/50
# 161/161 [==============================] - 12s 73ms/step - loss: 0.0304 - mse: 0.0304 - mae: 0.1326 - val_loss: 0.0300 - val_mse: 0.0300 - val_mae: 0.1312
# Epoch 36/50
# 161/161 [==============================] - 12s 74ms/step - loss: 0.0304 - mse: 0.0304 - mae: 0.1326 - val_loss: 0.0300 - val_mse: 0.0300 - val_mae: 0.1314
# Epoch 37/50
# 161/161 [==============================] - 12s 73ms/step - loss: 0.0304 - mse: 0.0304 - mae: 0.1326 - val_loss: 0.0300 - val_mse: 0.0300 - val_mae: 0.1312
# Epoch 38/50
# 161/161 [==============================] - 12s 73ms/step - loss: 0.0304 - mse: 0.0304 - mae: 0.1326 - val_loss: 0.0300 - val_mse: 0.0300 - val_mae: 0.1311
# Epoch 39/50
# 161/161 [==============================] - 12s 73ms/step - loss: 0.0304 - mse: 0.0304 - mae: 0.1326 - val_loss: 0.0300 - val_mse: 0.0300 - val_mae: 0.1314
# Epoch 40/50
# 161/161 [==============================] - 12s 73ms/step - loss: 0.0304 - mse: 0.0304 - mae: 0.1325 - val_loss: 0.0300 - val_mse: 0.0300 - val_mae: 0.1312
# Epoch 41/50
# 161/161 [==============================] - 12s 73ms/step - loss: 0.0304 - mse: 0.0304 - mae: 0.1326 - val_loss: 0.0299 - val_mse: 0.0299 - val_mae: 0.1314
# Epoch 42/50
# 161/161 [==============================] - 12s 73ms/step - loss: 0.0304 - mse: 0.0304 - mae: 0.1326 - val_loss: 0.0301 - val_mse: 0.0301 - val_mae: 0.1314
# Epoch 43/50
# 161/161 [==============================] - 12s 73ms/step - loss: 0.0304 - mse: 0.0304 - mae: 0.1325 - val_loss: 0.0300 - val_mse: 0.0300 - val_mae: 0.1313
# Epoch 44/50
# 161/161 [==============================] - 12s 73ms/step - loss: 0.0304 - mse: 0.0304 - mae: 0.1325 - val_loss: 0.0301 - val_mse: 0.0301 - val_mae: 0.1313
# Epoch 45/50
# 161/161 [==============================] - 12s 73ms/step - loss: 0.0304 - mse: 0.0304 - mae: 0.1325 - val_loss: 0.0299 - val_mse: 0.0299 - val_mae: 0.1312
# Epoch 46/50
# 161/161 [==============================] - 12s 73ms/step - loss: 0.0304 - mse: 0.0304 - mae: 0.1324 - val_loss: 0.0299 - val_mse: 0.0299 - val_mae: 0.1311
# Epoch 47/50
# 161/161 [==============================] - 12s 73ms/step - loss: 0.0304 - mse: 0.0304 - mae: 0.1324 - val_loss: 0.0300 - val_mse: 0.0300 - val_mae: 0.1311
# Epoch 48/50
# 161/161 [==============================] - 12s 73ms/step - loss: 0.0304 - mse: 0.0304 - mae: 0.1325 - val_loss: 0.0300 - val_mse: 0.0300 - val_mae: 0.1310
# Epoch 49/50
# 161/161 [==============================] - 12s 73ms/step - loss: 0.0303 - mse: 0.0303 - mae: 0.1324 - val_loss: 0.0299 - val_mse: 0.0299 - val_mae: 0.1312
# Epoch 50/50
# 161/161 [==============================] - 12s 73ms/step - loss: 0.0304 - mse: 0.0304 - mae: 0.1325 - val_loss: 0.0301 - val_mse: 0.0301 - val_mae: 0.1312

# %% [markdown]
# ##### Salva i tempi di allenamento

# %%
if train_and_save == True:
    dictionary = {
        "gru": time_gru,
        "lstm": time_lstm,
        "bidirectional": time_bi,
        "time2vec": time_t2v,
        "cnn": time_cnn,
        "transformer": time_t
    }

    with open("./trained_model/SleepDuration/training_times.json", "w") as outfile:
        json.dump(dictionary, outfile)
        
        
        
with open("./trained_model/SleepDuration/training_times.json", 'r') as openfile:
    dict_times = json.load(openfile)

# %%
if train_and_save == True:
    dictionary = {
        "gru": history_gru.history,
        "lstm": history_lstm.history,
        "bidirectional": history_bi.history,
        "time2vec": history_t2v.history,
        "cnn": history_cnn.history,
        "transformer": history_t.history
    }

    with open("./trained_model/SleepDuration/training_histories.json", "w") as outfile:
        json.dump(dictionary, outfile)
        
        
with open("./trained_model/SleepDuration/training_histories.json", 'r') as openfile:
    dict_histories = json.load(openfile)

# %% [markdown]
# # Plot

# %%
print("--- GRU ---\n\nTime: " + str(dict_times['gru']))
metrics(model_gru, trainX, trainY, testX, testY, dict_histories['gru'])
# Out:
# --- GRU ---
#
# Time: 208.44231462478638
# **********TRAIN-SET***********
# MSE: 0.030008506029844284
# RMSE: 0.1732296338097044
# MAE: 0.13119946420192719
# **********TEST-SET***********
# MSE: 0.029784010723233223
# RMSE: 0.17258044710578666
# MAE: 0.13089139759540558

# %%
print("--- LSTM ---\n\nTime: " + str(dict_times['lstm']))
metrics(model_lstm, trainX, trainY, testX, testY, dict_histories['lstm'])
# Out:
# --- LSTM ---
#
# Time: 226.15812873840332
# **********TRAIN-SET***********
# MSE: 0.030074574053287506
# RMSE: 0.17342022388777933
# MAE: 0.13173800706863403
# **********TEST-SET***********
# MSE: 0.02984575182199478
# RMSE: 0.17275923078664937
# MAE: 0.13139289617538452

# %%
print("--- Bidirectional ---\n\nTime: " + str(dict_times['bidirectional']))
metrics(model_bi, trainX, trainY, testX, testY, dict_histories['bidirectional'])
# Out:
# --- Bidirectional ---
#
# Time: 518.1531949043274
# **********TRAIN-SET***********
# MSE: 0.03012191876769066
# RMSE: 0.17355667307162423
# MAE: 0.13171568512916565
# **********TEST-SET***********
# MSE: 0.029869915917515755
# RMSE: 0.1728291523948311
# MAE: 0.13125434517860413

# %%
print("--- Time2Vec - LSTM ---\n\nTime: " + str(dict_times['time2vec']))
metrics(model_t2v, trainX, trainY, testX, testY, dict_histories['time2vec'])
# Out:
# --- Time2Vec - LSTM ---
#
# Time: 125.95113706588745
# **********TRAIN-SET***********
# MSE: 0.030090369284152985
# RMSE: 0.17346575824684532
# MAE: 0.13156083226203918
# **********TEST-SET***********
# MSE: 0.029841475188732147
# RMSE: 0.17274685290543543
# MAE: 0.1311446577310562

# %%
print("--- CNN - LSTM ---\n\nTime: " + str(dict_times['cnn']))
metrics(model_cnn, trainX, trainY, testX, testY, dict_histories['cnn'])
# Out:
# --- CNN - LSTM ---
#
# Time: 158.90628004074097
# **********TRAIN-SET***********
# MSE: 0.030209330841898918
# RMSE: 0.1738083163772635
# MAE: 0.1322486251592636
# **********TEST-SET***********
# MSE: 0.030283262953162193
# RMSE: 0.17402086930354702
# MAE: 0.1325197070837021

# %%
print("--- Transformer ---\n\nTime: " + str(time_t))
metrics(model_transformer, trainX, trainY, testX, testY, history_t.history)
# Out:
# --- Transformer ---
#
# Time: 605.0400977134705
# **********TRAIN-SET***********
# MSE: 0.030210886150598526
# RMSE: 0.17381279052646997
# MAE: 0.13140904903411865
# **********TEST-SET***********
# MSE: 0.029959535226225853
# RMSE: 0.1730882296004724
# MAE: 0.13094021379947662

# %%
price = [dict_times['time2vec'], dict_times['cnn'], dict_times['gru'], dict_times['lstm'], dict_times['bidirectional'],   time_t]
name = ['Time2Vec-LSTM',  'CNN-LSTM', 'GRU', 'LSTM', 'Bidirectional-LSTM', 'Transformer']
 
# Figure Size
fig, ax = plt.subplots(figsize =(16, 9))
 
# Horizontal Bar Plot
ax.bar(name, price)
 
# Remove axes splines
for s in ['top', 'bottom', 'left', 'right']:
    ax.spines[s].set_visible(False)

# Remove x, y Ticks
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')
 
# Add padding between axes and labels
ax.xaxis.set_tick_params(pad = 5)
ax.yaxis.set_tick_params(pad = 10)
 
# Add x, y gridlines
ax.grid(b = True, color ='grey', 
        linestyle ='-.', linewidth = 0.5,
        alpha = 0.2)
 

# Add annotation to bars
for i in ax.patches:
    plt.text(i.get_x()+0.27, i.get_height()+15,
             str(round((i.get_height()), 2)),
             fontsize = 13, fontweight ='bold',
             color ='grey')

# Add Plot Title
ax.set_title('Tempi di esecuzione [s]',
             loc ='center', fontsize = 15)
plt.rcParams.update({'font.size': 12})
# Show Plot
plt.show()
